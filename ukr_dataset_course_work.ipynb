# %% [markdown]
# <a href="https://colab.research.google.com/github/EugeneStrakhov86/it-in-analytics-fall-2018/blob/master/Pandas_in_action_(dou_ua)_(Apr_01_22%2C_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In my Colab notebook, I performed an analysis of salary data from the DOU.ua website to predict future salaries in the IT sector. I chose a dataset collected from surveys on DOU.ua between 2022 and 2024, which provides the most up-to-date and comprehensive information available. This dataset covers various factors influencing salary levels in the IT industry, and I used it to predict trends in future salaries within the field. In my project, I provided detailed visualizations to enhance the understanding of the data and support future research on salary prediction in the IT sector.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data reading: `read_csv()`
#
# Документація: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# Main Parameters:
#
# - `sep`: The delimiter for separating cells, default is a comma.
# - `header`: By default, set to 0, meaning the first row of the file is treated as the header.
# - `index_col`: The column number to be used as the index (i.e., "row labels").
# - `encoding`: The file encoding, default is UTF-8.
# - `parse_dates`: A list of columns to be parsed as dates.
# - `na_values`: Special values in the table that should be treated as missing data.

# %% [markdown]
# ## Спосіб 1. Простий
#
# Попробуємо прочитати дані, вказавши лише роздільник між комірками таблиці.

# %%
path = "/content/drive/MyDrive/2022_dec_raw.csv"
dou = pd.read_csv(path, sep=';')
dou.head()
# Out:
#              Timestamp  Ви працюєте зараз в ІТ?  \
# 0  11.30.2022 10:26:37    Так, працюю part-time
# 1  11.30.2022 10:26:39    Так, працюю full-time
# 2  11.30.2022 10:26:58    Так, працюю full-time
# 3  11.30.2022 10:27:31    Так, працюю full-time
# 4  11.30.2022 10:27:34  Ні, тимчасово не працюю
#
#                                 Де ви зараз живете?   \
# 0                                          В Україні
# 1  За кордоном (переїхали через війну, але планую...
# 2                                          В Україні
# 3                                          В Україні
# 4                                          В Україні
#
#   В якій області ви зараз живете?  \
# 0     Івано-Франківськ чи область
# 1                             NaN
# 2                 Київ чи область
# 3                Львів чи область
# 4              Житомир чи область
#
#   Зарплата у $$$ за місяць, лише ставка після сплати податків Ваша стать  \
# 0                                               4000             Чоловік
# 1                                                NaN             Чоловік
# 2                                               2500             Чоловік
# 3                                                500               Жінка
# 4                                               2800               Жінка
#
#   Ваш вік                     Яка у вас освіта? Чи є у вас науковий ступінь?   \
# 0      29  Вища (бакалавр, спеціаліст, магістр)                         Немає
# 1      36  Вища (бакалавр, спеціаліст, магістр)                         Немає
# 2      34  Вища (бакалавр, спеціаліст, магістр)                         Немає
# 3      23  Вища (бакалавр, спеціаліст, магістр)                         Немає
# 4      33  Вища (бакалавр, спеціаліст, магістр)                         Немає
#
#   Знання англійської мови  ... Ваша посада4 Ваша посада5 Ваша посада6  \
# 0            Intermediate  ...          NaN          NaN          NaN
# 1                Advanced  ...          NaN          NaN          NaN
# 2              Elementary  ...          NaN          NaN          NaN
# 3        Pre-Intermediate  ...          NaN          NaN          NaN
# 4      Upper-Intermediate  ...          NaN          NaN          NaN
#
#   Ваша посада7  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
#   Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                Ні, не використовую
# 4                                Ні, не використовую
#
#   Основна мова програмування Вкажіть вашу основну спеціалізацію  \
# 0                        NaN                                NaN
# 1                       Ruby                Full Stack розробка
# 2                  C# / .NET                Full Stack розробка
# 3                        NaN                                NaN
# 4                        NaN                                NaN
#
#                     В якій сфері працюєте? Тип компанії  \
# 0                               Blockchain      Стартап
# 1             Public services / Government   Продуктова
# 2  Adtech / Advertising, Security, Telecom   Продуктова
# 3                                  Telecom   Продуктова
# 4                               Automotive   Продуктова
#
#   Загальний стаж роботи за спеціальністю
# 0                                8 років
# 1                                 3 роки
# 2                                 4 роки
# 3                               Пів року
# 4                                6 років
#
# [5 rows x 28 columns]

# %% [markdown]
# Метод `info()` дозволяє отримати базову інформацію про датасет:
# * кількість рядків
# * кількість колонок
# * індекс
# * назви колонок
# * тип даних у колонках
# * наявність пропусків (null-значень)

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13315 entries, 0 to 13314
# Data columns (total 28 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Timestamp                                                                   13315 non-null  object
#  1   Ви працюєте зараз в ІТ?                                                     13315 non-null  object
#  2   Де ви зараз живете?                                                         13315 non-null  object
#  3   В якій області ви зараз живете?                                             11538 non-null  object
#  4   Зарплата у $$$ за місяць, лише ставка після сплати податків                 13288 non-null  object
#  5   Ваша стать                                                                  13315 non-null  object
#  6   Ваш вік                                                                     13315 non-null  object
#  7   Яка у вас освіта?                                                           13315 non-null  object
#  8   Чи є у вас науковий ступінь?                                                13204 non-null  object
#  9   Знання англійської мови                                                     13315 non-null  object
#  10  Оберіть вашу посаду                                                         13315 non-null  object
#  11  Ваш тайтл                                                                   13315 non-null  object
#  12  Ваша спеціалізація                                                          159 non-null    object
#  13  Вкажіть вашу спеціалізацію                                                  2364 non-null   object
#  14  Оберіть вашу спеціалізацію                                                  486 non-null    object
#  15  Ваша посада                                                                 305 non-null    object
#  16  Оберіть вашу посаду2                                                        560 non-null    object
#  17  Ваша посада3                                                                821 non-null    object
#  18  Ваша посада4                                                                485 non-null    object
#  19  Ваша посада5                                                                288 non-null    object
#  20  Ваша посада6                                                                353 non-null    object
#  21  Ваша посада7                                                                116 non-null    object
#  22  Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  4874 non-null   object
#  23  Основна мова програмування                                                  9060 non-null   object
#  24  Вкажіть вашу основну спеціалізацію                                          9059 non-null   object
#  25  В якій сфері працюєте?                                                      13315 non-null  object
#  26  Тип компанії                                                                13315 non-null  object
#  27  Загальний стаж роботи за спеціальністю                                      13315 non-null  object
# dtypes: object(28)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Спосіб 2. Розширений
#
# В якості індексу рядків можемо використати дату та час заповнення анкети (перша колонка таблиці). Потрібно розпізнати у `read_csv()` її як дату.

# %%
path = "/content/drive/MyDrive/2022_dec_raw.csv"
dou = pd.read_csv(path, sep=';', index_col=0, parse_dates=True)
dou.head()
# Out:
#                      Ви працюєте зараз в ІТ?  \
# Timestamp
# 11.30.2022 10:26:37    Так, працюю part-time
# 11.30.2022 10:26:39    Так, працюю full-time
# 11.30.2022 10:26:58    Так, працюю full-time
# 11.30.2022 10:27:31    Так, працюю full-time
# 11.30.2022 10:27:34  Ні, тимчасово не працюю
#
#                                                   Де ви зараз живете?   \
# Timestamp
# 11.30.2022 10:26:37                                          В Україні
# 11.30.2022 10:26:39  За кордоном (переїхали через війну, але планую...
# 11.30.2022 10:26:58                                          В Україні
# 11.30.2022 10:27:31                                          В Україні
# 11.30.2022 10:27:34                                          В Україні
#
#                     В якій області ви зараз живете?  \
# Timestamp
# 11.30.2022 10:26:37     Івано-Франківськ чи область
# 11.30.2022 10:26:39                             NaN
# 11.30.2022 10:26:58                 Київ чи область
# 11.30.2022 10:27:31                Львів чи область
# 11.30.2022 10:27:34              Житомир чи область
#
#                     Зарплата у $$$ за місяць, лише ставка після сплати податків  \
# Timestamp
# 11.30.2022 10:26:37                                               4000
# 11.30.2022 10:26:39                                                NaN
# 11.30.2022 10:26:58                                               2500
# 11.30.2022 10:27:31                                                500
# 11.30.2022 10:27:34                                               2800
#
#                     Ваша стать Ваш вік                     Яка у вас освіта?  \
# Timestamp
# 11.30.2022 10:26:37    Чоловік      29  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:26:39    Чоловік      36  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:26:58    Чоловік      34  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:27:31      Жінка      23  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:27:34      Жінка      33  Вища (бакалавр, спеціаліст, магістр)
#
#                     Чи є у вас науковий ступінь?  Знання англійської мови  \
# Timestamp
# 11.30.2022 10:26:37                         Немає            Intermediate
# 11.30.2022 10:26:39                         Немає                Advanced
# 11.30.2022 10:26:58                         Немає              Elementary
# 11.30.2022 10:27:31                         Немає        Pre-Intermediate
# 11.30.2022 10:27:34                         Немає      Upper-Intermediate
#
#                                                    Оберіть вашу посаду  ...  \
# Timestamp                                                               ...
# 11.30.2022 10:26:37  Designer / Artist (Graphic, UX/UI, Game, Artis...  ...
# 11.30.2022 10:26:39  Software Engineer (Junior, Middle, Senior, Tea...  ...
# 11.30.2022 10:26:58  Software Engineer (Junior, Middle, Senior, Tea...  ...
# 11.30.2022 10:27:31  QA Engineer (Junior, Middle, Senior, Team/Tech...  ...
# 11.30.2022 10:27:34  QA Engineer (Junior, Middle, Senior, Team/Tech...  ...
#
#                     Ваша посада4 Ваша посада5 Ваша посада6 Ваша посада7  \
# Timestamp
# 11.30.2022 10:26:37          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:39          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:58          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:31          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:34          NaN          NaN          NaN          NaN
#
#                     Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  \
# Timestamp
# 11.30.2022 10:26:37                                                NaN
# 11.30.2022 10:26:39                                                NaN
# 11.30.2022 10:26:58                                                NaN
# 11.30.2022 10:27:31                                Ні, не використовую
# 11.30.2022 10:27:34                                Ні, не використовую
#
#                     Основна мова програмування  \
# Timestamp
# 11.30.2022 10:26:37                        NaN
# 11.30.2022 10:26:39                       Ruby
# 11.30.2022 10:26:58                  C# / .NET
# 11.30.2022 10:27:31                        NaN
# 11.30.2022 10:27:34                        NaN
#
#                     Вкажіть вашу основну спеціалізацію  \
# Timestamp
# 11.30.2022 10:26:37                                NaN
# 11.30.2022 10:26:39                Full Stack розробка
# 11.30.2022 10:26:58                Full Stack розробка
# 11.30.2022 10:27:31                                NaN
# 11.30.2022 10:27:34                                NaN
#
#                                       В якій сфері працюєте? Тип компанії  \
# Timestamp
# 11.30.2022 10:26:37                               Blockchain      Стартап
# 11.30.2022 10:26:39             Public services / Government   Продуктова
# 11.30.2022 10:26:58  Adtech / Advertising, Security, Telecom   Продуктова
# 11.30.2022 10:27:31                                  Telecom   Продуктова
# 11.30.2022 10:27:34                               Automotive   Продуктова
#
#                     Загальний стаж роботи за спеціальністю
# Timestamp
# 11.30.2022 10:26:37                                8 років
# 11.30.2022 10:26:39                                 3 роки
# 11.30.2022 10:26:58                                 4 роки
# 11.30.2022 10:27:31                               Пів року
# 11.30.2022 10:27:34                                6 років
#
# [5 rows x 27 columns]

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 27 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Ви працюєте зараз в ІТ?                                                     13315 non-null  object
#  1   Де ви зараз живете?                                                         13315 non-null  object
#  2   В якій області ви зараз живете?                                             11538 non-null  object
#  3   Зарплата у $$$ за місяць, лише ставка після сплати податків                 13288 non-null  object
#  4   Ваша стать                                                                  13315 non-null  object
#  5   Ваш вік                                                                     13315 non-null  object
#  6   Яка у вас освіта?                                                           13315 non-null  object
#  7   Чи є у вас науковий ступінь?                                                13204 non-null  object
#  8   Знання англійської мови                                                     13315 non-null  object
#  9   Оберіть вашу посаду                                                         13315 non-null  object
#  10  Ваш тайтл                                                                   13315 non-null  object
#  11  Ваша спеціалізація                                                          159 non-null    object
#  12  Вкажіть вашу спеціалізацію                                                  2364 non-null   object
#  13  Оберіть вашу спеціалізацію                                                  486 non-null    object
#  14  Ваша посада                                                                 305 non-null    object
#  15  Оберіть вашу посаду2                                                        560 non-null    object
#  16  Ваша посада3                                                                821 non-null    object
#  17  Ваша посада4                                                                485 non-null    object
#  18  Ваша посада5                                                                288 non-null    object
#  19  Ваша посада6                                                                353 non-null    object
#  20  Ваша посада7                                                                116 non-null    object
#  21  Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  4874 non-null   object
#  22  Основна мова програмування                                                  9060 non-null   object
#  23  Вкажіть вашу основну спеціалізацію                                          9059 non-null   object
#  24  В якій сфері працюєте?                                                      13315 non-null  object
#  25  Тип компанії                                                                13315 non-null  object
#  26  Загальний стаж роботи за спеціальністю                                      13315 non-null  object
# dtypes: object(27)
# memory usage: 2.8+ MB

# %% [markdown]
# Виявилось, що числові колонки (зарплата та вік) не були розпізнані як числа. З'ясуємо, чому. Для цього додамо у `read_csv()` параметр `dtype` та вкажемо тип певних колонок в явному вигляді.

# %%
path = "/content/drive/MyDrive/2022_dec_raw.csv"
dou = pd.read_csv(path, sep=';', index_col=0, parse_dates=True,
                  dtype={'Зарплата у $$$ за місяць, лише ставка після сплати податків': np.float64,
                         'Ваш вік': np.float64})
dou.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9cb73f7fd46a> in <cell line: 2>()
#       1 path = "/content/drive/MyDrive/2022_dec_raw.csv"
# ----> 2 dou = pd.read_csv(path, sep=';', index_col=0, parse_dates=True,
#       3                   dtype={'Зарплата у $$$ за місяць, лише ставка після сплати податків': np.float64,
#       4                          'Ваш вік': np.float64})
#       5 dou.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     581
#     582     with parser:
# --> 583         return parser.read(nrows)
#     584
#     585
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: could not convert string to float: '1542,75'

# %% [markdown]
# Бачимо, що цілу та дробну частину розділяє кома. Додамо ще один параметр `decimal`, який відповідає за тип роздільника між цілою та дробною частинами.

# %%
path = "/content/drive/MyDrive/2022_dec_raw.csv"
dou = pd.read_csv(path, sep=';', index_col=0, parse_dates=True, decimal=','
                  #dtype={'Зарплата у $$$ за місяць, лише ставка після сплати податків': np.float64,
                         #'Ваш вік': np.float64}
                  )
dou.head()
# Out:
#                      Ви працюєте зараз в ІТ?  \
# Timestamp
# 11.30.2022 10:26:37    Так, працюю part-time
# 11.30.2022 10:26:39    Так, працюю full-time
# 11.30.2022 10:26:58    Так, працюю full-time
# 11.30.2022 10:27:31    Так, працюю full-time
# 11.30.2022 10:27:34  Ні, тимчасово не працюю
#
#                                                   Де ви зараз живете?   \
# Timestamp
# 11.30.2022 10:26:37                                          В Україні
# 11.30.2022 10:26:39  За кордоном (переїхали через війну, але планую...
# 11.30.2022 10:26:58                                          В Україні
# 11.30.2022 10:27:31                                          В Україні
# 11.30.2022 10:27:34                                          В Україні
#
#                     В якій області ви зараз живете?  \
# Timestamp
# 11.30.2022 10:26:37     Івано-Франківськ чи область
# 11.30.2022 10:26:39                             NaN
# 11.30.2022 10:26:58                 Київ чи область
# 11.30.2022 10:27:31                Львів чи область
# 11.30.2022 10:27:34              Житомир чи область
#
#                      Зарплата у $$$ за місяць, лише ставка після сплати податків  \
# Timestamp
# 11.30.2022 10:26:37                                             4000.0
# 11.30.2022 10:26:39                                                NaN
# 11.30.2022 10:26:58                                             2500.0
# 11.30.2022 10:27:31                                              500.0
# 11.30.2022 10:27:34                                             2800.0
#
#                     Ваша стать  Ваш вік                     Яка у вас освіта?  \
# Timestamp
# 11.30.2022 10:26:37    Чоловік     29.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:26:39    Чоловік     36.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:26:58    Чоловік     34.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:27:31      Жінка     23.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:27:34      Жінка     33.0  Вища (бакалавр, спеціаліст, магістр)
#
#                     Чи є у вас науковий ступінь?  Знання англійської мови  \
# Timestamp
# 11.30.2022 10:26:37                         Немає            Intermediate
# 11.30.2022 10:26:39                         Немає                Advanced
# 11.30.2022 10:26:58                         Немає              Elementary
# 11.30.2022 10:27:31                         Немає        Pre-Intermediate
# 11.30.2022 10:27:34                         Немає      Upper-Intermediate
#
#                                                    Оберіть вашу посаду  ...  \
# Timestamp                                                               ...
# 11.30.2022 10:26:37  Designer / Artist (Graphic, UX/UI, Game, Artis...  ...
# 11.30.2022 10:26:39  Software Engineer (Junior, Middle, Senior, Tea...  ...
# 11.30.2022 10:26:58  Software Engineer (Junior, Middle, Senior, Tea...  ...
# 11.30.2022 10:27:31  QA Engineer (Junior, Middle, Senior, Team/Tech...  ...
# 11.30.2022 10:27:34  QA Engineer (Junior, Middle, Senior, Team/Tech...  ...
#
#                     Ваша посада4 Ваша посада5 Ваша посада6 Ваша посада7  \
# Timestamp
# 11.30.2022 10:26:37          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:39          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:58          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:31          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:34          NaN          NaN          NaN          NaN
#
#                     Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  \
# Timestamp
# 11.30.2022 10:26:37                                                NaN
# 11.30.2022 10:26:39                                                NaN
# 11.30.2022 10:26:58                                                NaN
# 11.30.2022 10:27:31                                Ні, не використовую
# 11.30.2022 10:27:34                                Ні, не використовую
#
#                     Основна мова програмування  \
# Timestamp
# 11.30.2022 10:26:37                        NaN
# 11.30.2022 10:26:39                       Ruby
# 11.30.2022 10:26:58                  C# / .NET
# 11.30.2022 10:27:31                        NaN
# 11.30.2022 10:27:34                        NaN
#
#                     Вкажіть вашу основну спеціалізацію  \
# Timestamp
# 11.30.2022 10:26:37                                NaN
# 11.30.2022 10:26:39                Full Stack розробка
# 11.30.2022 10:26:58                Full Stack розробка
# 11.30.2022 10:27:31                                NaN
# 11.30.2022 10:27:34                                NaN
#
#                                       В якій сфері працюєте? Тип компанії  \
# Timestamp
# 11.30.2022 10:26:37                               Blockchain      Стартап
# 11.30.2022 10:26:39             Public services / Government   Продуктова
# 11.30.2022 10:26:58  Adtech / Advertising, Security, Telecom   Продуктова
# 11.30.2022 10:27:31                                  Telecom   Продуктова
# 11.30.2022 10:27:34                               Automotive   Продуктова
#
#                     Загальний стаж роботи за спеціальністю
# Timestamp
# 11.30.2022 10:26:37                                8 років
# 11.30.2022 10:26:39                                 3 роки
# 11.30.2022 10:26:58                                 4 роки
# 11.30.2022 10:27:31                               Пів року
# 11.30.2022 10:27:34                                6 років
#
# [5 rows x 27 columns]

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 27 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Ви працюєте зараз в ІТ?                                                     13315 non-null  object
#  1   Де ви зараз живете?                                                         13315 non-null  object
#  2   В якій області ви зараз живете?                                             11538 non-null  object
#  3   Зарплата у $$$ за місяць, лише ставка після сплати податків                 13288 non-null  float64
#  4   Ваша стать                                                                  13315 non-null  object
#  5   Ваш вік                                                                     13315 non-null  float64
#  6   Яка у вас освіта?                                                           13315 non-null  object
#  7   Чи є у вас науковий ступінь?                                                13204 non-null  object
#  8   Знання англійської мови                                                     13315 non-null  object
#  9   Оберіть вашу посаду                                                         13315 non-null  object
#  10  Ваш тайтл                                                                   13315 non-null  object
#  11  Ваша спеціалізація                                                          159 non-null    object
#  12  Вкажіть вашу спеціалізацію                                                  2364 non-null   object
#  13  Оберіть вашу спеціалізацію                                                  486 non-null    object
#  14  Ваша посада                                                                 305 non-null    object
#  15  Оберіть вашу посаду2                                                        560 non-null    object
#  16  Ваша посада3                                                                821 non-null    object
#  17  Ваша посада4                                                                485 non-null    object
#  18  Ваша посада5                                                                288 non-null    object
#  19  Ваша посада6                                                                353 non-null    object
#  20  Ваша посада7                                                                116 non-null    object
#  21  Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?  4874 non-null   object
#  22  Основна мова програмування                                                  9060 non-null   object
#  23  Вкажіть вашу основну спеціалізацію                                          9059 non-null   object
#  24  В якій сфері працюєте?                                                      13315 non-null  object
#  25  Тип компанії                                                                13315 non-null  object
#  26  Загальний стаж роботи за спеціальністю                                      13315 non-null  object
# dtypes: float64(2), object(25)
# memory usage: 2.8+ MB

# %%
dou.describe()
# Out:
#              salary           age
# count  13288.000000  13315.000000
# mean    3011.820647     29.319001
# std     2057.391947      6.033420
# min       50.000000     14.000000
# 25%     1300.000000     25.000000
# 50%     2600.000000     29.000000
# 75%     4300.000000     33.000000
# max    19500.000000     63.000000

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Renaming columns

# %% [markdown]
# Подивимось, чи є зайві пробіли у назвах стовпчиків.

# %%
dou.columns
# Out:
# Index(['Ви працюєте зараз в ІТ?', 'Де ви зараз живете? ',
#        'В якій області ви зараз живете?',
#        'Зарплата у $$$ за місяць, лише ставка після сплати податків',
#        'Ваша стать', 'Ваш вік', 'Яка у вас освіта?',
#        'Чи є у вас науковий ступінь? ', 'Знання англійської мови',
#        'Оберіть вашу посаду', 'Ваш тайтл', 'Ваша спеціалізація',
#        'Вкажіть вашу спеціалізацію', 'Оберіть вашу спеціалізацію',
#        'Ваша посада', 'Оберіть вашу посаду2', 'Ваша посада3', 'Ваша посада4',
#        'Ваша посада5', 'Ваша посада6', 'Ваша посада7',
#        'Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?',
#        'Основна мова програмування', 'Вкажіть вашу основну спеціалізацію',
#        'В якій сфері працюєте?', 'Тип компанії',
#        'Загальний стаж роботи за спеціальністю'],
#       dtype='object')

# %% [markdown]
# Є зайві пробіли. Видаляємо їх за допомогою методу `strip()` класу `str`.

# %%
dou.columns = dou.columns.str.strip()

# %%
dou.columns
# Out:
# Index(['Ви працюєте зараз в ІТ?', 'Де ви зараз живете?',
#        'В якій області ви зараз живете?',
#        'Зарплата у $$$ за місяць, лише ставка після сплати податків',
#        'Ваша стать', 'Ваш вік', 'Яка у вас освіта?',
#        'Чи є у вас науковий ступінь?', 'Знання англійської мови',
#        'Оберіть вашу посаду', 'Ваш тайтл', 'Ваша спеціалізація',
#        'Вкажіть вашу спеціалізацію', 'Оберіть вашу спеціалізацію',
#        'Ваша посада', 'Оберіть вашу посаду2', 'Ваша посада3', 'Ваша посада4',
#        'Ваша посада5', 'Ваша посада6', 'Ваша посада7',
#        'Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?',
#        'Основна мова програмування', 'Вкажіть вашу основну спеціалізацію',
#        'В якій сфері працюєте?', 'Тип компанії',
#        'Загальний стаж роботи за спеціальністю'],
#       dtype='object')

# %% [markdown]
# Тепер виконуємо перейменування за допомогою методу `rename()`. Для цього потрібно створити словник (mapper), ключами якого є старі назви колонок, а значеннями --- нові назви.

# %%
mapper = {
    'Ви працюєте зараз в ІТ?': 'employment_type',
    'Де ви зараз живете?': 'city',
    'В якій області ви зараз живете?': 'region',
    'Зарплата у $$$ за місяць, лише ставка після сплати податків': 'salary',
    'Ваша стать': 'gender',
    'Ваш вік': 'age',
    'Яка у вас освіта?': 'education',
    'Чи є у вас науковий ступінь?': 'scientific_degree',
    'Знання англійської мови': 'english_level',
    'Ваш тайтл': 'title',
    'Чи використовуєте ви у своїй роботі мови програмування (одну чи декілька)?': 'use_code',
    'Основна мова програмування': 'programming_language',
    'В якій сфері працюєте?': 'area',
    'Тип компанії': 'company_type',
    'Загальний стаж роботи за спеціальністю': 'work_experience'
}

# %%
dou = dou.rename(columns=mapper)

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   employment_type                     13315 non-null  object
#  1   city                                13315 non-null  object
#  2   region                              11538 non-null  object
#  3   salary                              13288 non-null  float64
#  4   gender                              13315 non-null  object
#  5   age                                 13315 non-null  float64
#  6   education                           13315 non-null  object
#  7   scientific_degree                   13204 non-null  object
#  8   english_level                       13315 non-null  object
#  9   Оберіть вашу посаду                 13315 non-null  object
#  10  title                               13315 non-null  object
#  11  Ваша спеціалізація                  159 non-null    object
#  12  Вкажіть вашу спеціалізацію          2364 non-null   object
#  13  Оберіть вашу спеціалізацію          486 non-null    object
#  14  Ваша посада                         305 non-null    object
#  15  Оберіть вашу посаду2                560 non-null    object
#  16  Ваша посада3                        821 non-null    object
#  17  Ваша посада4                        485 non-null    object
#  18  Ваша посада5                        288 non-null    object
#  19  Ваша посада6                        353 non-null    object
#  20  Ваша посада7                        116 non-null    object
#  21  use_code                            4874 non-null   object
#  22  programming_language                9060 non-null   object
#  23  Вкажіть вашу основну спеціалізацію  9059 non-null   object
#  24  area                                13315 non-null  object
#  25  company_type                        13315 non-null  object
#  26  work_experience                     13315 non-null  object
# dtypes: float64(2), object(25)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Data Transformation. Handling Missing Values
#
# Let's handle the "position" and "specialization" columns. We can observe that there is some duplication between them.
#
# We will slice the dataset based on columns that contain position-related information. To do this, we will use the `concat()` method, which allows us to concatenate dataframes (either horizontally or vertically).
#
# Docs and examples https://pandas.pydata.org/docs/reference/api/pandas.concat.html

# %%
positions = pd.concat([dou['Оберіть вашу посаду'], dou.loc[:, 'Ваша посада':'Ваша посада7']], axis=1)

# %%
positions.head()
# Out:
#                                                    Оберіть вашу посаду  \
# Timestamp
# 11.30.2022 10:26:37  Designer / Artist (Graphic, UX/UI, Game, Artis...
# 11.30.2022 10:26:39  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:26:58  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:27:31  QA Engineer (Junior, Middle, Senior, Team/Tech...
# 11.30.2022 10:27:34  QA Engineer (Junior, Middle, Senior, Team/Tech...
#
#                     Ваша посада Оберіть вашу посаду2 Ваша посада3  \
# Timestamp
# 11.30.2022 10:26:37         NaN                  NaN          NaN
# 11.30.2022 10:26:39         NaN                  NaN          NaN
# 11.30.2022 10:26:58         NaN                  NaN          NaN
# 11.30.2022 10:27:31         NaN                  NaN          NaN
# 11.30.2022 10:27:34         NaN                  NaN          NaN
#
#                     Ваша посада4 Ваша посада5 Ваша посада6 Ваша посада7
# Timestamp
# 11.30.2022 10:26:37          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:39          NaN          NaN          NaN          NaN
# 11.30.2022 10:26:58          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:31          NaN          NaN          NaN          NaN
# 11.30.2022 10:27:34          NaN          NaN          NaN          NaN

# %% [markdown]
# Бачимо, що перша з колонок ("Оберіть вашу посаду") повна. Подивимось, які значення записані у інших колонках. Так як дані категоріальні, використаємо  метод `value_counts()`.

# %%
""" Visualize the Numerical Features """
def visualize_num_feature(train_df):
    plt.figure(figsize = (14, 6))
    plt.subplot(1,2,1)
    sns.boxplot(train_df)
    plt.subplot(1,2,2)
    sns.distplot(train_df, bins=20)
    plt.show()

""" Use IQR rule to identify potential outliers"""
def stat_summary(train_df):
    stat =  train_df.describe()
    print(stat)
    IQR = stat['75%'] - stat['25%']
    upper = stat['75%'] + 1.5 * IQR
    lower = stat['25%'] - 1.5 * IQR
    print('The upper and lower bounds for suspected outliers are {} and {}' .format(upper, lower))

# %%
### salary
print('Visulaize target varibale (salary)')
visualize_num_feature(dou['salary'])
stat_summary(dou['salary'])
# Out:
# Visulaize target varibale (salary)
# <ipython-input-22-338d5215f386>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df, bins=20)
# count    13288.000000
# mean      3011.820647
# std       2057.391947
# min         50.000000
# 25%       1300.000000
# 50%       2600.000000
# 75%       4300.000000
# max      19500.000000
# Name: salary, dtype: float64
# The upper and lower bounds for suspected outliers are 8800.0 and -3200.0

# %%
# Out:
# Numerical types columns name:
#  ['salary', 'age']
#
#
# Categorical types columns name:
#  ['employment_type', 'city', 'region', 'gender', 'education', 'scientific_degree', 'english_level', 'Оберіть вашу посаду', 'title', 'Ваша спеціалізація', 'Вкажіть вашу спеціалізацію', 'Оберіть вашу спеціалізацію', 'Ваша посада', 'Оберіть вашу посаду2', 'Ваша посада3', 'Ваша посада4', 'Ваша посада5', 'Ваша посада6', 'Ваша посада7', 'use_code', 'programming_language', 'Вкажіть вашу основну спеціалізацію', 'area', 'company_type', 'work_experience']

# %%
num_int_type = dou.select_dtypes(include='int64').columns.tolist()
num_float_type = dou.select_dtypes(include='float64').columns.tolist()
num_type = num_int_type + num_float_type
print("\nNumerical types columns name: \n", num_type)

cat_object_type = dou.select_dtypes(include='object').columns.tolist()
print("\n\nCategorical types columns name: \n", cat_object_type)
corr_matrix = dou[num_type].corr()
display(corr_matrix)

print(" Heat map for categorical columns: ")
plt.subplots(figsize=(6,5))
# Out:
# Numerical types columns name:
#  ['salary', 'age', 'work_experience']
#
#
# Categorical types columns name:
#  ['employment_type', 'region', 'gender', 'education', 'scientific_degree', 'english_level', 'position', 'title', 'programming_language', 'specialization', 'area', 'company_type', 'specialization_info']
#                    salary       age  work_experience
# salary           1.000000  0.287106         0.546924
# age              0.287106  1.000000         0.560513
# work_experience  0.546924  0.560513         1.000000
#  Heat map for categorical columns:
# (<Figure size 600x500 with 1 Axes>, <Axes: >)

# %%
numeric_dou = dou.select_dtypes(include=['int64', 'float64'])

# Побудова кореляційної матриці
correlation_matrix = numeric_dou.corr()

# Візуалізація теплової карти
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Теплова карта кореляційної матриці', fontsize=16)
plt.show()

# %%
dou['Ваша посада'].value_counts()
# Out:
# Ваша посада
# Other                            44
# Marketing Manager                44
# SEO Specialist                   34
# Digital Marketing Manager        33
# Copywriter                       27
# Chief Marketing Officer (CMO)    22
# Employer Brand Manager           20
# SMM Manager                      20
# PR Manager                       16
# Product Marketing Manager        11
# Email Marketing Specialist       10
# PPC Specialist                    8
# Media Buyer                       8
# Account Manager                   6
# Link Builder                      2
# Name: count, dtype: int64

# %%
# Візуалізуємо розподіл
counts = dou['Ваша посада'].value_counts()

plt.figure(figsize=(10, 6))
counts.plot(kind='bar')
plt.title('Розподіл посад')
plt.xlabel('Посада')
plt.ylabel('Кількість')
plt.xticks(rotation=45)  # Повернути підписи осі X для зручності
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 8))
counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Розподіл посад')
plt.ylabel('')  # Відключаємо підпис осі Y
plt.tight_layout()
plt.show()

# %%
counts_1 = dou['Ваша посада'].value_counts()
counts_2 = dou['Оберіть вашу посаду2'].value_counts()
dou['Ваша посада3'].value_counts()
dou['Ваша посада4'].value_counts()
dou['Ваша посада5'].value_counts()

# Об'єднання розподілів
merged_counts = counts_1.add(counts_2, fill_value=0)

# Візуалізуємо розподіл у формі стовпчикової діаграми
plt.figure(figsize=(12, 6))
merged_counts.sort_values(ascending=False).plot(kind='bar')
plt.title('Об\'єднаний розподіл посад')
plt.xlabel('Посада')
plt.ylabel('Кількість')
plt.xticks(rotation=45)  # Повернути підписи осі X для зручності
plt.tight_layout()
plt.show()

# %%
dou['Оберіть вашу посаду2'].value_counts()
# Out:
# Recruiter                             201
# HR Manager                            131
# Talent Acquisition Manager             52
# Talent Researcher/Sourcer              51
# HR Director                            45
# HR Business Partner                    40
# People partner / Happiness manager     40
# Name: Оберіть вашу посаду2, dtype: int64

# %%
dou['Ваша посада3'].value_counts()
# Out:
# Project Manager     443
# Product Manager     135
# Delivery Manager     88
# Product Owner        67
# Scrum Master         42
# Program Manager      29
# Business Manager     17
# Name: Ваша посада3, dtype: int64

# %%
dou['Ваша посада4'].value_counts()
# Out:
# Business Analyst    289
# Data Analyst        106
# Product Analyst      34
# System Analyst       32
# BI Analyst           24
# Name: Ваша посада4, dtype: int64

# %%
dou['Ваша посада5'].value_counts()
# Out:
# Data Engineer / Big Data Engineer    104
# Data Scientist                        93
# Machine Learning Engineer             46
# Computer Vision Engineer              21
# Research Engineer                     15
# BI Engineer                            9
# Name: Ваша посада5, dtype: int64

# %%
dou['Ваша посада6'].value_counts()
# Out:
# DevOps Engineer              325
# Site Reliability Engineer     28
# Name: Ваша посада6, dtype: int64

# %%
dou['Ваша посада7'].value_counts()
# Out:
# CTO                        41
# Director of Engineering    33
# CEO, (co-) founder         28
# Program Director           14
# Name: Ваша посада7, dtype: int64

# %% [markdown]
# Схоже на те, що у колонках 2-8 записані конкретні найменування посад з групи, яка вказана у першій колонці. Перевіримо це на прикладах.

# %%
positions[~positions['Ваша посада'].isna()].head(10)
# Out:
#                             Оберіть вашу посаду  \
# Timestamp
# 2022-11-30 10:41:20  Marketing, SEO, Copywriter
# 2022-11-30 11:42:56  Marketing, SEO, Copywriter
# 2022-11-30 11:55:39  Marketing, SEO, Copywriter
# 2022-11-30 12:07:15  Marketing, SEO, Copywriter
# 2022-11-30 12:33:51  Marketing, SEO, Copywriter
# 2022-11-30 12:48:39  Marketing, SEO, Copywriter
# 2022-11-30 12:50:08  Marketing, SEO, Copywriter
# 2022-11-30 12:59:47  Marketing, SEO, Copywriter
# 2022-11-30 13:04:33  Marketing, SEO, Copywriter
# 2022-11-30 13:06:13  Marketing, SEO, Copywriter
#
#                                        Ваша посада Оберіть вашу посаду2  \
# Timestamp
# 2022-11-30 10:41:20                          Other                  NaN
# 2022-11-30 11:42:56     Email Marketing Specialist                  NaN
# 2022-11-30 11:55:39  Chief Marketing Officer (CMO)                  NaN
# 2022-11-30 12:07:15     Email Marketing Specialist                  NaN
# 2022-11-30 12:33:51                     PR Manager                  NaN
# 2022-11-30 12:48:39         Employer Brand Manager                  NaN
# 2022-11-30 12:50:08                     Copywriter                  NaN
# 2022-11-30 12:59:47              Marketing Manager                  NaN
# 2022-11-30 13:04:33      Product Marketing Manager                  NaN
# 2022-11-30 13:06:13              Marketing Manager                  NaN
#
#                     Ваша посада3 Ваша посада4 Ваша посада5 Ваша посада6  \
# Timestamp
# 2022-11-30 10:41:20          NaN          NaN          NaN          NaN
# 2022-11-30 11:42:56          NaN          NaN          NaN          NaN
# 2022-11-30 11:55:39          NaN          NaN          NaN          NaN
# 2022-11-30 12:07:15          NaN          NaN          NaN          NaN
# 2022-11-30 12:33:51          NaN          NaN          NaN          NaN
# 2022-11-30 12:48:39          NaN          NaN          NaN          NaN
# 2022-11-30 12:50:08          NaN          NaN          NaN          NaN
# 2022-11-30 12:59:47          NaN          NaN          NaN          NaN
# 2022-11-30 13:04:33          NaN          NaN          NaN          NaN
# 2022-11-30 13:06:13          NaN          NaN          NaN          NaN
#
#                     Ваша посада7
# Timestamp
# 2022-11-30 10:41:20          NaN
# 2022-11-30 11:42:56          NaN
# 2022-11-30 11:55:39          NaN
# 2022-11-30 12:07:15          NaN
# 2022-11-30 12:33:51          NaN
# 2022-11-30 12:48:39          NaN
# 2022-11-30 12:50:08          NaN
# 2022-11-30 12:59:47          NaN
# 2022-11-30 13:04:33          NaN
# 2022-11-30 13:06:13          NaN

# %%
positions[~positions['Ваша посада7'].isna()].head(10)
# Out:
#                                                    Оберіть вашу посаду  \
# Timestamp
# 2022-11-30 11:25:10  СTO, Director of Engineering, Program Director...
# 2022-11-30 11:43:37  СTO, Director of Engineering, Program Director...
# 2022-11-30 12:07:53  СTO, Director of Engineering, Program Director...
# 2022-11-30 12:23:25  СTO, Director of Engineering, Program Director...
# 2022-11-30 12:24:39  СTO, Director of Engineering, Program Director...
# 2022-11-30 13:00:35  СTO, Director of Engineering, Program Director...
# 2022-11-30 15:25:08  СTO, Director of Engineering, Program Director...
# 2022-11-30 18:12:29  СTO, Director of Engineering, Program Director...
# 2022-11-30 18:30:16  СTO, Director of Engineering, Program Director...
# 2022-11-30 19:24:39  СTO, Director of Engineering, Program Director...
#
#                     Ваша посада Оберіть вашу посаду2 Ваша посада3  \
# Timestamp
# 2022-11-30 11:25:10         NaN                  NaN          NaN
# 2022-11-30 11:43:37         NaN                  NaN          NaN
# 2022-11-30 12:07:53         NaN                  NaN          NaN
# 2022-11-30 12:23:25         NaN                  NaN          NaN
# 2022-11-30 12:24:39         NaN                  NaN          NaN
# 2022-11-30 13:00:35         NaN                  NaN          NaN
# 2022-11-30 15:25:08         NaN                  NaN          NaN
# 2022-11-30 18:12:29         NaN                  NaN          NaN
# 2022-11-30 18:30:16         NaN                  NaN          NaN
# 2022-11-30 19:24:39         NaN                  NaN          NaN
#
#                     Ваша посада4 Ваша посада5 Ваша посада6  \
# Timestamp
# 2022-11-30 11:25:10          NaN          NaN          NaN
# 2022-11-30 11:43:37          NaN          NaN          NaN
# 2022-11-30 12:07:53          NaN          NaN          NaN
# 2022-11-30 12:23:25          NaN          NaN          NaN
# 2022-11-30 12:24:39          NaN          NaN          NaN
# 2022-11-30 13:00:35          NaN          NaN          NaN
# 2022-11-30 15:25:08          NaN          NaN          NaN
# 2022-11-30 18:12:29          NaN          NaN          NaN
# 2022-11-30 18:30:16          NaN          NaN          NaN
# 2022-11-30 19:24:39          NaN          NaN          NaN
#
#                                 Ваша посада7
# Timestamp
# 2022-11-30 11:25:10                      CTO
# 2022-11-30 11:43:37  Director of Engineering
# 2022-11-30 12:07:53       CEO, (co-) founder
# 2022-11-30 12:23:25                      CTO
# 2022-11-30 12:24:39  Director of Engineering
# 2022-11-30 13:00:35         Program Director
# 2022-11-30 15:25:08  Director of Engineering
# 2022-11-30 18:12:29       CEO, (co-) founder
# 2022-11-30 18:30:16       CEO, (co-) founder
# 2022-11-30 19:24:39       CEO, (co-) founder

# %% [markdown]
# Наша здогадка вірна. Тепер з'єднаємо стовпчики 2-8 в один стовпчик (можемо назвати його "уточнена посада").
#
# Для цього використаємо метод `bfill()`: https://www.geeksforgeeks.org/python-pandas-dataframe-bfill/
#
# bfill (backfill) є одним зі способів заповнення пропусків: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html#pandas.DataFrame.fillna

# %%
dou['positions_info'] = positions.iloc[:, 1:].fillna(method='bfill', axis=1).iloc[:, 0]
dou['positions_info'].value_counts(dropna=False) # показуємо разом з пропущеними значеннями
# Out:
# NaN                                   10387
# Project Manager                         443
# DevOps Engineer                         325
# Business Analyst                        289
# Recruiter                               201
# Product Manager                         135
# HR Manager                              131
# Data Analyst                            106
# Data Engineer / Big Data Engineer       104
# Data Scientist                           93
# Delivery Manager                         88
# Product Owner                            67
# Talent Acquisition Manager               52
# Talent Researcher/Sourcer                51
# Machine Learning Engineer                46
# HR Director                              45
# Other                                    44
# Marketing Manager                        44
# Scrum Master                             42
# CTO                                      41
# People partner / Happiness manager       40
# HR Business Partner                      40
# Product Analyst                          34
# SEO Specialist                           34
# Director of Engineering                  33
# Digital Marketing Manager                33
# System Analyst                           32
# Program Manager                          29
# CEO, (co-) founder                       28
# Site Reliability Engineer                28
# Copywriter                               27
# BI Analyst                               24
# Chief Marketing Officer (CMO)            22
# Computer Vision Engineer                 21
# Employer Brand Manager                   20
# SMM Manager                              20
# Business Manager                         17
# PR Manager                               16
# Research Engineer                        15
# Program Director                         14
# Product Marketing Manager                11
# Email Marketing Specialist               10
# BI Engineer                               9
# PPC Specialist                            8
# Media Buyer                               8
# Account Manager                           6
# Link Builder                              2
# Name: positions_info, dtype: int64

# %%
positions['positions_info'] = positions.iloc[:, 1:].fillna(method='bfill', axis=1).iloc[:, 0]

# Порахуємо розподіл значень зі стовпця positions_info без NaN
counts = positions['positions_info'].value_counts()

# Візуалізуємо розподіл у формі стовпчикової діаграми
plt.figure(figsize=(12, 6))
counts.sort_values(ascending=False).plot(kind='bar')
plt.title('Розподіл позицій', fontsize=16)
plt.xlabel('Значення', fontsize=14)
plt.ylabel('Кількість', fontsize=14)
plt.xticks(rotation=90, fontsize=10)  # Повернути підписи осі X та змінити розмір шрифту
plt.tight_layout()
plt.show()

# %%
counts
# Out:
# positions_info
# Project Manager                       443
# DevOps Engineer                       325
# Business Analyst                      289
# Recruiter                             201
# Product Manager                       135
# HR Manager                            131
# Data Analyst                          106
# Data Engineer / Big Data Engineer     104
# Data Scientist                         93
# Delivery Manager                       88
# Product Owner                          67
# Talent Acquisition Manager             52
# Talent Researcher/Sourcer              51
# Machine Learning Engineer              46
# HR Director                            45
# Other                                  44
# Marketing Manager                      44
# Scrum Master                           42
# CTO                                    41
# HR Business Partner                    40
# People partner / Happiness manager     40
# SEO Specialist                         34
# Product Analyst                        34
# Director of Engineering                33
# Digital Marketing Manager              33
# System Analyst                         32
# Program Manager                        29
# CEO, (co-) founder                     28
# Site Reliability Engineer              28
# Copywriter                             27
# BI Analyst                             24
# Chief Marketing Officer (CMO)          22
# Computer Vision Engineer               21
# SMM Manager                            20
# Employer Brand Manager                 20
# Business Manager                       17
# PR Manager                             16
# Research Engineer                      15
# Program Director                       14
# Product Marketing Manager              11
# Email Marketing Specialist             10
# BI Engineer                             9
# PPC Specialist                          8
# Media Buyer                             8
# Account Manager                         6
# Link Builder                            2
# Name: count, dtype: int64

# %% [markdown]
# Це з'єднання можливо було виконати й іншим способом: спочатку замінити усі пропуски (`NaN`) на пустий текст (`''`), а потім скласти всі колонки як текстові значення.

# %%
for col in positions.columns[1:]:
  positions[col] = positions[col].fillna('')

# %%
positions['positions_info'] = positions['Ваша посада'] + positions['Оберіть вашу посаду2'] + positions['Ваша посада3'] + positions['Ваша посада4'] + positions['Ваша посада5'] + positions['Ваша посада6'] + positions['Ваша посада7']

# %%
positions['positions_info'].value_counts()
# Out:
# positions_info
#                                       10387
# Project Manager                         443
# DevOps Engineer                         325
# Business Analyst                        289
# Recruiter                               201
# Product Manager                         135
# HR Manager                              131
# Data Analyst                            106
# Data Engineer / Big Data Engineer       104
# Data Scientist                           93
# Delivery Manager                         88
# Product Owner                            67
# Talent Acquisition Manager               52
# Talent Researcher/Sourcer                51
# Machine Learning Engineer                46
# HR Director                              45
# Other                                    44
# Marketing Manager                        44
# Scrum Master                             42
# CTO                                      41
# People partner / Happiness manager       40
# HR Business Partner                      40
# Product Analyst                          34
# SEO Specialist                           34
# Director of Engineering                  33
# Digital Marketing Manager                33
# System Analyst                           32
# Program Manager                          29
# CEO, (co-) founder                       28
# Site Reliability Engineer                28
# Copywriter                               27
# BI Analyst                               24
# Chief Marketing Officer (CMO)            22
# Computer Vision Engineer                 21
# Employer Brand Manager                   20
# SMM Manager                              20
# Business Manager                         17
# PR Manager                               16
# Research Engineer                        15
# Program Director                         14
# Product Marketing Manager                11
# Email Marketing Specialist               10
# BI Engineer                               9
# PPC Specialist                            8
# Media Buyer                               8
# Account Manager                           6
# Link Builder                              2
# Name: count, dtype: int64

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   employment_type                     13315 non-null  object
#  1   city                                13315 non-null  object
#  2   region                              11538 non-null  object
#  3   salary                              13288 non-null  float64
#  4   gender                              13315 non-null  object
#  5   age                                 13315 non-null  float64
#  6   education                           13315 non-null  object
#  7   scientific_degree                   13204 non-null  object
#  8   english_level                       13315 non-null  object
#  9   Оберіть вашу посаду                 13315 non-null  object
#  10  title                               13315 non-null  object
#  11  Ваша спеціалізація                  159 non-null    object
#  12  Вкажіть вашу спеціалізацію          2364 non-null   object
#  13  Оберіть вашу спеціалізацію          486 non-null    object
#  14  Ваша посада                         305 non-null    object
#  15  Оберіть вашу посаду2                560 non-null    object
#  16  Ваша посада3                        821 non-null    object
#  17  Ваша посада4                        485 non-null    object
#  18  Ваша посада5                        288 non-null    object
#  19  Ваша посада6                        353 non-null    object
#  20  Ваша посада7                        116 non-null    object
#  21  use_code                            4874 non-null   object
#  22  programming_language                9060 non-null   object
#  23  Вкажіть вашу основну спеціалізацію  9059 non-null   object
#  24  area                                13315 non-null  object
#  25  company_type                        13315 non-null  object
#  26  work_experience                     13315 non-null  object
#  27  specialization_info                 3009 non-null   object
# dtypes: float64(2), object(26)
# memory usage: 2.9+ MB

# %% [markdown]
# Залишається перейменувати колонку "Оберіть вашу посаду" та видалити зайві колонки.

# %%
dou = dou.rename(columns={'Оберіть вашу посаду': 'position'})
columns_to_delete = dou.columns[14:21]
print(columns_to_delete)
# Out:
# Index(['Ваша посада', 'Оберіть вашу посаду2', 'Ваша посада3', 'Ваша посада4',
#        'Ваша посада5', 'Ваша посада6', 'Ваша посада7'],
#       dtype='object')

# %% [markdown]
# Для видалення колонок або рядків використовуємо метод `drop()`.

# %%
dou = dou.drop(columns_to_delete, axis=1)
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   employment_type                     13315 non-null  object
#  1   city                                13315 non-null  object
#  2   region                              11538 non-null  object
#  3   salary                              13288 non-null  float64
#  4   gender                              13315 non-null  object
#  5   age                                 13315 non-null  float64
#  6   education                           13315 non-null  object
#  7   scientific_degree                   13204 non-null  object
#  8   english_level                       13315 non-null  object
#  9   position                            13315 non-null  object
#  10  title                               13315 non-null  object
#  11  Ваша спеціалізація                  159 non-null    object
#  12  Вкажіть вашу спеціалізацію          2364 non-null   object
#  13  Оберіть вашу спеціалізацію          486 non-null    object
#  14  use_code                            4874 non-null   object
#  15  programming_language                9060 non-null   object
#  16  Вкажіть вашу основну спеціалізацію  9059 non-null   object
#  17  area                                13315 non-null  object
#  18  company_type                        13315 non-null  object
#  19  work_experience                     13315 non-null  object
#  20  specialization_info                 3009 non-null   object
# dtypes: float64(2), object(19)
# memory usage: 2.2+ MB

# %% [markdown]
# Аналогічним способом опрацюємо групу колонок щодо спеціалізації.

# %%
spec = pd.concat([dou.iloc[:, 11:14], dou.iloc[:, 16]], axis=1)
spec.head()
# Out:
#                     Ваша спеціалізація Вкажіть вашу спеціалізацію  \
# Timestamp
# 11.30.2022 10:26:37                NaN                        NaN
# 11.30.2022 10:26:39                NaN                        NaN
# 11.30.2022 10:26:58                NaN                        NaN
# 11.30.2022 10:27:31                NaN                  Manual QA
# 11.30.2022 10:27:34                NaN                  Manual QA
#
#                     Оберіть вашу спеціалізацію  \
# Timestamp
# 11.30.2022 10:26:37           Product Designer
# 11.30.2022 10:26:39                        NaN
# 11.30.2022 10:26:58                        NaN
# 11.30.2022 10:27:31                        NaN
# 11.30.2022 10:27:34                        NaN
#
#                     Вкажіть вашу основну спеціалізацію
# Timestamp
# 11.30.2022 10:26:37                                NaN
# 11.30.2022 10:26:39                Full Stack розробка
# 11.30.2022 10:26:58                Full Stack розробка
# 11.30.2022 10:27:31                                NaN
# 11.30.2022 10:27:34                                NaN

# %%
spec['Ваша спеціалізація'].value_counts()
# Out:
# Ваша спеціалізація
# Programmer                       89
# Gameplay Programmer              42
# Engine Programmer                 8
# .NET Programmer                   6
# Ul Programmer                     4
# Rendering/Graphics Programmer     4
# Al Programmer                     3
# Інше                              3
# Name: count, dtype: int64

# %%
spec['Вкажіть вашу спеціалізацію'].value_counts()
# Out:
# Вкажіть вашу спеціалізацію
# Manual QA         1467
# Automation QA      531
# General QA         354
# Performance QA      12
# Name: count, dtype: int64

# %%
spec['Оберіть вашу спеціалізацію'].value_counts()
# Out:
# Оберіть вашу спеціалізацію
# UI/UX Designer              201
# Product Designer             60
# 3D Artist                    40
# 2D Artist                    35
# Graphic / Video Designer     33
# Game Designer                20
# Designer                     15
# Animator                     14
# Other                        12
# Web Designer                 11
# UI/UX Artist                  7
# Character Artist              7
# Level Designer                5
# Tech Game Designer            5
# Concept artist                4
# VFX Artist                    4
# Art Director                  3
# Environment Artist            3
# Illustrator                   3
# Sound Designer                3
# Vehicle Artist                1
# Name: count, dtype: int64

# %%
spec['Вкажіть вашу основну спеціалізацію'].value_counts()
# Out:
# Вкажіть вашу основну спеціалізацію
# Back-end  розробка               2847
# Full Stack розробка              1628
# Front-end  розробка              1628
# QA                               1079
# Mobile  розробка                  665
# Робота з даними, аналіз даних     558
# DevOps                            308
# Інше                              293
# Embedded                           49
# embedded                            2
# Embedded                            1
# embedded                            1
# Name: count, dtype: int64

# %%
spec['Вкажіть вашу основну спеціалізацію'].unique()
# Out:
# array([nan, 'Full Stack розробка', 'Back-end  розробка', 'QA',
#        'Front-end  розробка', 'Робота з даними, аналіз даних',
#        'Mobile  розробка', 'Інше', 'DevOps', 'Embedded ', 'Embedded',
#        'embedded ', 'embedded'], dtype=object)

# %%
spec['Вкажіть вашу основну спеціалізацію'] = spec['Вкажіть вашу основну спеціалізацію'].str.strip()
spec['Вкажіть вашу основну спеціалізацію'].unique()
# Out:
# array([nan, 'Full Stack розробка', 'Back-end  розробка', 'QA',
#        'Front-end  розробка', 'Робота з даними, аналіз даних',
#        'Mobile  розробка', 'Інше', 'DevOps', 'Embedded', 'embedded'],
#       dtype=object)

# %%
spec['Вкажіть вашу основну спеціалізацію'] = spec['Вкажіть вашу основну спеціалізацію'].str.replace('embedded', 'Embedded')

# %%
dou['specialization_info'] = spec.iloc[:, :3].fillna(method='bfill', axis=1).iloc[:, 0]
dou['Вкажіть вашу основну спеціалізацію'] = spec['Вкажіть вашу основну спеціалізацію']
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   employment_type                     13315 non-null  object
#  1   city                                13315 non-null  object
#  2   region                              11538 non-null  object
#  3   salary                              13288 non-null  float64
#  4   gender                              13315 non-null  object
#  5   age                                 13315 non-null  float64
#  6   education                           13315 non-null  object
#  7   scientific_degree                   13204 non-null  object
#  8   english_level                       13315 non-null  object
#  9   position                            13315 non-null  object
#  10  title                               13315 non-null  object
#  11  Ваша спеціалізація                  159 non-null    object
#  12  Вкажіть вашу спеціалізацію          2364 non-null   object
#  13  Оберіть вашу спеціалізацію          486 non-null    object
#  14  use_code                            4874 non-null   object
#  15  programming_language                9060 non-null   object
#  16  Вкажіть вашу основну спеціалізацію  9059 non-null   object
#  17  area                                13315 non-null  object
#  18  company_type                        13315 non-null  object
#  19  work_experience                     13315 non-null  object
#  20  specialization_info                 3009 non-null   object
# dtypes: float64(2), object(19)
# memory usage: 2.2+ MB

# %%
counts = spec['Вкажіть вашу основну спеціалізацію'].value_counts()

# Візуалізуємо розподіл у формі стовпчикової діаграми
plt.figure(figsize=(12, 6))
counts.sort_values(ascending=False).plot(kind='bar')
plt.title('Розподіл основних спеціалізацій', fontsize=16)
plt.xlabel('Спеціалізація', fontsize=14)
plt.ylabel('Кількість', fontsize=14)
plt.xticks(rotation=45, fontsize=12)  # Повернути підписи осі X та змінити розмір шрифту
plt.tight_layout()
plt.show()

# %%
dou = dou.rename(columns={'Вкажіть вашу основну спеціалізацію': 'specialization'})
dou = dou.drop(dou.columns[11:14], axis=1)
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13315 non-null  object
#  1   city                  13315 non-null  object
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13315 non-null  object
#  5   age                   13315 non-null  float64
#  6   education             13315 non-null  object
#  7   scientific_degree     13204 non-null  object
#  8   english_level         13315 non-null  object
#  9   position              13315 non-null  object
#  10  title                 13315 non-null  object
#  11  use_code              4874 non-null   object
#  12  programming_language  9060 non-null   object
#  13  specialization        9059 non-null   object
#  14  area                  13315 non-null  object
#  15  company_type          13315 non-null  object
#  16  work_experience       13315 non-null  object
#  17  specialization_info   3009 non-null   object
# dtypes: float64(2), object(16)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Changing Column Types
#
# Common situations where it might be necessary (or beneficial) to change the data type in a column, particularly for categorical columns:
#
# - Convert to boolean values (e.g., `{'yes': True, 'no': False}`).
# - Replace ordinal values with numeric values (e.g., `{'high': 2, 'medium': 1, 'low': 0}`).
# - Extract numeric values from text.
#
# In particular, categorical columns containing only two unique categories are often transformed into binary (boolean) values.

# %%
dou['city'].value_counts()
# Out:
# city
# В Україні                                                      11587
# За кордоном (переїхали через війну, але планую повернутися)     1728
# Name: count, dtype: int64

# %%
counts = dou['city'].value_counts()


plt.figure(figsize=(8, 8))
counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Розподіл місцеположення')
plt.ylabel('')  # Відключаємо підпис осі Y
plt.tight_layout()
plt.show()

# %%
dou = dou.rename(columns={'city': 'in_ukraine'})
dou['in_ukraine'] = dou['in_ukraine'] == 'В Україні' # перетворення за допомогою маски
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13315 non-null  object
#  1   in_ukraine            13315 non-null  bool
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13315 non-null  object
#  5   age                   13315 non-null  float64
#  6   education             13315 non-null  object
#  7   scientific_degree     13204 non-null  object
#  8   english_level         13315 non-null  object
#  9   position              13315 non-null  object
#  10  title                 13315 non-null  object
#  11  use_code              4874 non-null   object
#  12  programming_language  9060 non-null   object
#  13  specialization        9059 non-null   object
#  14  area                  13315 non-null  object
#  15  company_type          13315 non-null  object
#  16  work_experience       13315 non-null  object
#  17  specialization_info   3009 non-null   object
# dtypes: bool(1), float64(2), object(15)
# memory usage: 1.8+ MB

# %%
dou['employment_type'].value_counts() # не можна ніяк перетворити
# Out:
# employment_type
# Так, працюю full-time      12643
# Ні, тимчасово не працюю      380
# Так, працюю part-time        152
# Так, я фрилансер             115
# Інше                          25
# Name: count, dtype: int64

# %%
counts = dou['employment_type'].value_counts()

# Візуалізуємо розподіл у формі кругової діаграми
plt.figure(figsize=(8, 8))
counts.plot(kind='pie', autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.title('Розподіл типів зайнятості')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
dou['scientific_degree'].value_counts() # можна перетворити на числову (рангову) змінну
# Out:
# scientific_degree
# Немає                  12980
# Кандидат наук / PhD      216
# Доктор наук                8
# Name: count, dtype: int64

# %%
dou['use_code'].value_counts() # можна перетворити на булеву, але пам'ятаймо про NaN!
# Out:
# use_code
# Ні, не використовую    2754
# Так, використовую      2120
# Name: count, dtype: int64

# %%
dou['use_code'] = dou['use_code'].map({'Ні, не використовую': False, 'Так, використовую': True})
dou['use_code'].value_counts(dropna=False)
# Out:
# use_code
# NaN      8441
# False    2754
# True     2120
# Name: count, dtype: int64

# %%
dou['use_code'] = dou['use_code'].astype('boolean') # "безпечне" перетворення на булевий тип
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13315 non-null  object
#  1   in_ukraine            13315 non-null  bool
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13315 non-null  object
#  5   age                   13315 non-null  float64
#  6   education             13315 non-null  object
#  7   scientific_degree     13204 non-null  object
#  8   english_level         13315 non-null  object
#  9   position              13315 non-null  object
#  10  title                 13315 non-null  object
#  11  use_code              4874 non-null   boolean
#  12  programming_language  9060 non-null   object
#  13  specialization        9059 non-null   object
#  14  area                  13315 non-null  object
#  15  company_type          13315 non-null  object
#  16  work_experience       13315 non-null  object
#  17  specialization_info   3009 non-null   object
# dtypes: bool(1), boolean(1), float64(2), object(14)
# memory usage: 1.8+ MB

# %%
dou['use_code'].value_counts(dropna=False)
# Out:
# use_code
# <NA>     8441
# False    2754
# True     2120
# Name: count, dtype: Int64

# %% [markdown]
# ## Transforming Columns with Custom Functions
# Sometimes it's not possible to perform transformations using standard functions or methods from the Pandas library. In such cases, we can write a custom Python function and apply it to the values in a column using map() or apply().

# %%
dou['work_experience'].value_counts()
# Out:
# work_experience
# 3 роки               1608
# 4 роки               1447
# 2 роки               1427
# 5 років              1351
# 1,5 року             1056
# 6 років               982
# 1 рік                 922
# 7 років               791
# 10 років              599
# 15 і більше років     586
# 8 років               529
# Пів року              457
# Менше як 3 місяці     434
# 9 років               336
# 11 років              233
# 12 років              206
# 3 місяці              158
# 13 років               97
# 14 років               96
# Name: count, dtype: int64

# %%
def exp_to_num(text):
  '''
  Функція для перетворення текстового значення досвіду роботи у число (років).
  '''
  if text == '3 місяці':
    return 0.25
  first = text.split()[0]
  if first == '1,5':
    return 1.5
  elif first == 'Пів':
    return 0.5
  elif first == 'Менше':
    return 0
  else:
    return float(first)

# %%
dou['work_experience'] = dou['work_experience'].map(exp_to_num)

# %%
counts = dou['work_experience'].value_counts()

# Візуалізуємо розподіл у формі кругової діаграми
plt.figure(figsize=(8, 8))
counts.plot(kind='pie', autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.title('Розподіл років досвіду роботи')
plt.ylabel('')
plt.tight_layout()
plt.show()

# Візуалізуємо розподіл у формі стовпчикової діаграми
plt.figure(figsize=(10, 6))
counts.sort_index().plot(kind='bar', color='skyblue')
plt.title('Розподіл досвіду роботи')
plt.xlabel('Рівень досвіду')
plt.ylabel('Кількість')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13315 non-null  object
#  1   in_ukraine            13315 non-null  bool
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13315 non-null  object
#  5   age                   13315 non-null  float64
#  6   education             13315 non-null  object
#  7   scientific_degree     13204 non-null  object
#  8   english_level         13315 non-null  object
#  9   position              13315 non-null  object
#  10  title                 13315 non-null  object
#  11  use_code              4874 non-null   boolean
#  12  programming_language  9060 non-null   object
#  13  specialization        9059 non-null   object
#  14  area                  13315 non-null  object
#  15  company_type          13315 non-null  object
#  16  work_experience       13315 non-null  float64
#  17  specialization_info   3009 non-null   object
# dtypes: bool(1), boolean(1), float64(3), object(13)
# memory usage: 1.8+ MB

# %%
dou.describe()
# Out:
#              salary           age  work_experience
# count  13288.000000  13315.000000     13315.000000
# mean    3011.820647     29.319001         4.814119
# std     2057.391947      6.033420         3.796924
# min       50.000000     14.000000         0.000000
# 25%     1300.000000     25.000000         2.000000
# 50%     2600.000000     29.000000         4.000000
# 75%     4300.000000     33.000000         7.000000
# max    19500.000000     63.000000        15.000000

# %% [markdown]
# ## Saving a "clean" DataFrame to a CSV file

# %%
path_to_write = "/content/drive/MyDrive/IT in Analytics/Python/Spring 2023/2022_dec_cleaned.csv"
dou.to_csv(path_to_write)

# %% [markdown]
# ##Preliminary Analytics: Exploratory Data Analysis (EDA)

# %%
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13315 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13315 non-null  object
#  1   in_ukraine            13315 non-null  bool
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13315 non-null  object
#  5   age                   13315 non-null  float64
#  6   education             13315 non-null  object
#  7   scientific_degree     13204 non-null  object
#  8   english_level         13315 non-null  object
#  9   position              13315 non-null  object
#  10  title                 13315 non-null  object
#  11  use_code              4874 non-null   boolean
#  12  programming_language  9060 non-null   object
#  13  specialization        9059 non-null   object
#  14  area                  13315 non-null  object
#  15  company_type          13315 non-null  object
#  16  work_experience       13315 non-null  float64
#  17  specialization_info   3009 non-null   object
# dtypes: bool(1), boolean(1), float64(3), object(13)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Simple Statistics

# %% [markdown]
# Для виведення базової статистичної інформації за кількісними данними користуємось методом `describe()`.

# %%
dou['salary'].describe()
# Out:
# count    13288.000000
# mean      3011.820647
# std       2057.391947
# min         50.000000
# 25%       1300.000000
# 50%       2600.000000
# 75%       4300.000000
# max      19500.000000
# Name: salary, dtype: float64

# %% [markdown]
# Для візуалізації розподілу кількісних неперервних даних можна побудувати гістограму.

# %%
dou['salary'].plot(kind='hist')
plt.xlabel('Salary, $ per month')
plt.title('Histogram of Salary')
plt.show()

# %% [markdown]
# Проаналізуємо 10 мінімальних та 10 максимальних значень зарплат у датасеті. Можливо, такі дані містять помилки.

# %%
min_10_salaries = dou['salary'].nsmallest(10)
dou[dou['salary'].isin(min_10_salaries)].sort_values('salary')
# Out:
#                              employment_type  in_ukraine  \
# Timestamp
# 12.13.2022 12:46:46    Так, працюю part-time        True
# 12.10.2022 10:15       Так, працюю full-time        True
# 11.30.2022 11:54:02    Так, працюю full-time        True
# 12.06.2022 16:19       Так, працюю full-time        True
# 12.10.2022 00:08     Ні, тимчасово не працюю        True
# 12.12.2022 16:52       Так, працюю full-time        True
# 12.27.2022 17:07:38    Так, працюю full-time        True
# 12.03.2022 14:21       Так, працюю full-time        True
# 12.12.2022 19:07     Ні, тимчасово не працюю        True
# 12.06.2022 15:11       Так, працюю full-time        True
#
#                                    region  salary   gender   age  \
# Timestamp
# 12.13.2022 12:46:46     Харків чи область    50.0  Чоловік  42.0
# 12.10.2022 10:15          Київ чи область    80.0    Жінка  29.0
# 11.30.2022 11:54:02    Вінниця чи область   100.0  Чоловік  19.0
# 12.06.2022 16:19       Вінниця чи область   100.0  Чоловік  18.0
# 12.10.2022 00:08          Київ чи область   100.0  Чоловік  21.0
# 12.12.2022 16:52        Дніпро чи область   100.0  Чоловік  28.0
# 12.27.2022 17:07:38    Полтава чи область   100.0  Чоловік  14.0
# 12.03.2022 14:21       Полтава чи область   130.0  Чоловік  31.0
# 12.12.2022 19:07     Тернопіль чи область   130.0  Чоловік  33.0
# 12.06.2022 15:11        Дніпро чи область   144.0  Чоловік  31.0
#
#                                                 education scientific_degree  \
# Timestamp
# 12.13.2022 12:46:46                    Середня спеціальна             Немає
# 12.10.2022 10:15     Вища (бакалавр, спеціаліст, магістр)             Немає
# 11.30.2022 11:54:02  Вища (бакалавр, спеціаліст, магістр)             Немає
# 12.06.2022 16:19                       Середня спеціальна             Немає
# 12.10.2022 00:08                          Ще студент вишу             Немає
# 12.12.2022 16:52                       Середня спеціальна             Немає
# 12.27.2022 17:07:38                               Середня               NaN
# 12.03.2022 14:21                                 Дві вищі             Немає
# 12.12.2022 19:07     Вища (бакалавр, спеціаліст, магістр)             Немає
# 12.06.2022 15:11     Вища (бакалавр, спеціаліст, магістр)             Немає
#
#                           english_level  \
# Timestamp
# 12.13.2022 12:46:46          Elementary
# 12.10.2022 10:15       Pre-Intermediate
# 11.30.2022 11:54:02  Upper-Intermediate
# 12.06.2022 16:19           Intermediate
# 12.10.2022 00:08           Intermediate
# 12.12.2022 16:52             Elementary
# 12.27.2022 17:07:38    Pre-Intermediate
# 12.03.2022 14:21       Pre-Intermediate
# 12.12.2022 19:07       Pre-Intermediate
# 12.06.2022 15:11       Pre-Intermediate
#
#                                                               position  \
# Timestamp
# 12.13.2022 12:46:46                                         HTML Coder
# 12.10.2022 10:15                            Marketing, SEO, Copywriter
# 11.30.2022 11:54:02  Software Engineer (Junior, Middle, Senior, Tea...
# 12.06.2022 16:19     Software Engineer (Junior, Middle, Senior, Tea...
# 12.10.2022 00:08              Data Science, Machine Learning, Big Data
# 12.12.2022 16:52     Software Engineer (Junior, Middle, Senior, Tea...
# 12.27.2022 17:07:38                                         HTML Coder
# 12.03.2022 14:21     QA Engineer (Junior, Middle, Senior, Team/Tech...
# 12.12.2022 19:07     QA Engineer (Junior, Middle, Senior, Team/Tech...
# 12.06.2022 15:11     Software Engineer (Junior, Middle, Senior, Tea...
#
#                               title  use_code programming_language  \
# Timestamp
# 12.13.2022 12:46:46          Junior      True                  PHP
# 12.10.2022 10:15       Немає тайтлу      <NA>                  NaN
# 11.30.2022 11:54:02  Intern/Trainee      <NA>            C# / .NET
# 12.06.2022 16:19     Intern/Trainee      <NA>                 Java
# 12.10.2022 00:08     Intern/Trainee      True               Python
# 12.12.2022 16:52             Junior      <NA>           JavaScript
# 12.27.2022 17:07:38    Немає тайтлу      True           JavaScript
# 12.03.2022 14:21     Intern/Trainee     False                  NaN
# 12.12.2022 19:07             Junior      True               Python
# 12.06.2022 15:11             Middle      <NA>                  C++
#
#                                     specialization  \
# Timestamp
# 12.13.2022 12:46:46            Full Stack розробка
# 12.10.2022 10:15                               NaN
# 11.30.2022 11:54:02            Full Stack розробка
# 12.06.2022 16:19                Back-end  розробка
# 12.10.2022 00:08     Робота з даними, аналіз даних
# 12.12.2022 16:52               Front-end  розробка
# 12.27.2022 17:07:38            Front-end  розробка
# 12.03.2022 14:21                               NaN
# 12.12.2022 19:07                                QA
# 12.06.2022 15:11                              Інше
#
#                                                area   company_type  \
# Timestamp
# 12.13.2022 12:46:46  E-commerce, Edtech / Education     Продуктова
# 12.10.2022 10:15                         E-commerce     Продуктова
# 11.30.2022 11:54:02   E-commerce, High Load Systems  Аутстафінгова
# 12.06.2022 16:19                        Media, Інша  Аутсорсингова
# 12.10.2022 00:08                           Big Data           Інша
# 12.12.2022 16:52                         E-commerce     Продуктова
# 12.27.2022 17:07:38                            Інша           Інша
# 12.03.2022 14:21                               Інша           Інша
# 12.12.2022 19:07                               Інша     Продуктова
# 12.06.2022 15:11                 Edtech / Education           Інша
#
#                      work_experience specialization_info
# Timestamp
# 12.13.2022 12:46:46             7.00                 NaN
# 12.10.2022 10:15                2.00                 NaN
# 11.30.2022 11:54:02             0.00                 NaN
# 12.06.2022 16:19                0.50                 NaN
# 12.10.2022 00:08                0.00                 NaN
# 12.12.2022 16:52                2.00                 NaN
# 12.27.2022 17:07:38             0.00                 NaN
# 12.03.2022 14:21                0.25           Manual QA
# 12.12.2022 19:07               10.00           Manual QA
# 12.06.2022 15:11                2.00                 NaN

# %%
top_10_salaries = dou['salary'].nlargest(10)
dou[dou['salary'].isin(top_10_salaries)].sort_values('salary', ascending=False)
# Out:
#                            employment_type  in_ukraine            region  \
# Timestamp
# 12.01.2022 14:33     Так, працюю full-time       False               NaN
# 12.01.2022 17:37     Так, працюю full-time       False               NaN
# 11.30.2022 11:42:58  Так, працюю full-time        True   Київ чи область
# 11.30.2022 16:55:10  Так, працюю full-time       False               NaN
# 12.06.2022 23:34     Так, працюю full-time        True   Київ чи область
# 12.10.2022 14:26     Так, працюю full-time       False               NaN
# 12.02.2022 19:46     Так, працюю full-time       False               NaN
# 11.30.2022 16:50:46  Так, працюю full-time        True  Львів чи область
# 12.01.2022 12:28     Так, працюю full-time        True   Київ чи область
# 12.12.2022 10:57     Так, працюю full-time       False               NaN
#
#                       salary   gender   age  \
# Timestamp
# 12.01.2022 14:33     19500.0  Чоловік  28.0
# 12.01.2022 17:37     17000.0  Чоловік  33.0
# 11.30.2022 11:42:58  16000.0  Чоловік  32.0
# 11.30.2022 16:55:10  16000.0  Чоловік  32.0
# 12.06.2022 23:34     16000.0  Чоловік  32.0
# 12.10.2022 14:26     14687.0  Чоловік  33.0
# 12.02.2022 19:46     14500.0  Чоловік  41.0
# 11.30.2022 16:50:46  14000.0  Чоловік  25.0
# 12.01.2022 12:28     14000.0  Чоловік  25.0
# 12.12.2022 10:57     14000.0  Чоловік  29.0
#
#                                                 education scientific_degree  \
# Timestamp
# 12.01.2022 14:33     Вища (бакалавр, спеціаліст, магістр)             Немає
# 12.01.2022 17:37                                 Дві вищі             Немає
# 11.30.2022 11:42:58  Вища (бакалавр, спеціаліст, магістр)             Немає
# 11.30.2022 16:55:10                              Дві вищі             Немає
# 12.06.2022 23:34                                  Середня             Немає
# 12.10.2022 14:26                       Середня спеціальна             Немає
# 12.02.2022 19:46     Вища (бакалавр, спеціаліст, магістр)             Немає
# 11.30.2022 16:50:46  Вища (бакалавр, спеціаліст, магістр)             Немає
# 12.01.2022 12:28     Вища (бакалавр, спеціаліст, магістр)             Немає
# 12.12.2022 10:57                       Середня спеціальна             Немає
#
#                           english_level  \
# Timestamp
# 12.01.2022 14:33     Upper-Intermediate
# 12.01.2022 17:37               Advanced
# 11.30.2022 11:42:58  Upper-Intermediate
# 11.30.2022 16:55:10        Intermediate
# 12.06.2022 23:34               Advanced
# 12.10.2022 14:26               Advanced
# 12.02.2022 19:46     Upper-Intermediate
# 11.30.2022 16:50:46            Advanced
# 12.01.2022 12:28     Upper-Intermediate
# 12.12.2022 10:57               Advanced
#
#                                                               position  \
# Timestamp
# 12.01.2022 14:33     Software Engineer (Junior, Middle, Senior, Tea...
# 12.01.2022 17:37     Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 11:42:58                                        DevOps, SRE
# 11.30.2022 16:55:10  Software Engineer (Junior, Middle, Senior, Tea...
# 12.06.2022 23:34     Software Engineer (Junior, Middle, Senior, Tea...
# 12.10.2022 14:26     Designer / Artist (Graphic, UX/UI, Game, Artis...
# 12.02.2022 19:46                                           DevOps, SRE
# 11.30.2022 16:50:46  Software Engineer (Junior, Middle, Senior, Tea...
# 12.01.2022 12:28     Software Engineer (Junior, Middle, Senior, Tea...
# 12.12.2022 10:57     СTO, Director of Engineering, Program Director...
#
#                             title  use_code              programming_language  \
# Timestamp
# 12.01.2022 14:33        Architect      <NA>                              Java
# 12.01.2022 17:37           Senior      <NA>                                 C
# 11.30.2022 11:42:58        Senior     False                               NaN
# 11.30.2022 16:55:10        Senior      <NA>                        JavaScript
# 12.06.2022 23:34        Architect      <NA>  Не можу обрати одну основну мову
# 12.10.2022 14:26     Немає тайтлу      <NA>                               NaN
# 12.02.2022 19:46        Tech Lead     False                               NaN
# 11.30.2022 16:50:46          Head      <NA>                        TypeScript
# 12.01.2022 12:28           Senior      <NA>                        JavaScript
# 12.12.2022 10:57     Немає тайтлу      True                            Python
#
#                           specialization  \
# Timestamp
# 12.01.2022 14:33      Back-end  розробка
# 12.01.2022 17:37      Back-end  розробка
# 11.30.2022 11:42:58                  NaN
# 11.30.2022 16:55:10  Front-end  розробка
# 12.06.2022 23:34     Full Stack розробка
# 12.10.2022 14:26                     NaN
# 12.02.2022 19:46                     NaN
# 11.30.2022 16:50:46  Full Stack розробка
# 12.01.2022 12:28     Front-end  розробка
# 12.12.2022 10:57     Full Stack розробка
#
#                                                                   area  \
# Timestamp
# 12.01.2022 14:33                Big Data, Internet of Things, Security
# 12.01.2022 17:37                                              Embedded
# 11.30.2022 11:42:58                                Data Science, Media
# 11.30.2022 16:55:10                      Blockchain, Fintech / Banking
# 12.06.2022 23:34     Cloud Computing, Fintech / Banking, High Load ...
# 12.10.2022 14:26                                              Hardware
# 12.02.2022 19:46                    Cloud Computing, Fintech / Banking
# 11.30.2022 16:50:46                               Big Data, Blockchain
# 12.01.2022 12:28                                            E-commerce
# 12.12.2022 10:57                     Big Data, Legal, Machine Learning
#
#                       company_type  work_experience specialization_info
# Timestamp
# 12.01.2022 14:33     Аутсорсингова              8.0                 NaN
# 12.01.2022 17:37        Продуктова              9.0                 NaN
# 11.30.2022 11:42:58     Продуктова              9.0                 NaN
# 11.30.2022 16:55:10        Стартап             10.0                 NaN
# 12.06.2022 23:34        Продуктова             15.0                 NaN
# 12.10.2022 14:26           Стартап             10.0    Product Designer
# 12.02.2022 19:46     Аутстафінгова              8.0                 NaN
# 11.30.2022 16:50:46     Продуктова             10.0                 NaN
# 12.01.2022 12:28     Аутстафінгова              7.0                 NaN
# 12.12.2022 10:57        Продуктова             12.0                 NaN

# %% [markdown]
# Тепер проаналізуємо пропущені дані.

# %%
# % пропущених значень у колонці "зарплата"
dou['salary'].isnull().sum() / dou.shape[0] * 100
# Out:
# 0.20277882087870822

# %%
dou[dou['salary'].isnull()]
# Out:
#                              employment_type  in_ukraine region  salary  \
# Timestamp
# 11.30.2022 10:26:39    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:28:00    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:30:00    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:30:30    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:30:53    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:34:00    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:35:35    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:36:24    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:36:56    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:37:46    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:39:44    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:39:47    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:43:29    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:45:02    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:45:45    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:45:48    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:46:12    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:49:02    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:49:16    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:49:39    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:50:29    Так, працюю part-time       False    NaN     NaN
# 11.30.2022 10:50:57    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:56:11    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 10:56:26    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 11:00:43    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 11:03:31    Так, працюю full-time       False    NaN     NaN
# 11.30.2022 11:30:53  Ні, тимчасово не працюю       False    NaN     NaN
#
#                       gender   age                             education  \
# Timestamp
# 11.30.2022 10:26:39  Чоловік  36.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:28:00  Чоловік  17.0                       Ще студент вишу
# 11.30.2022 10:30:00  Чоловік  22.0                       Ще студент вишу
# 11.30.2022 10:30:30    Жінка  26.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:30:53  Чоловік  22.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:34:00  Чоловік  21.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:35:35  Чоловік  34.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:36:24  Чоловік  28.0                              Дві вищі
# 11.30.2022 10:36:56    Жінка  37.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:37:46  Чоловік  27.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:39:44  Чоловік  33.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:39:47  Чоловік  20.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:43:29    Жінка  24.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:45:02  Чоловік  39.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:45:45  Чоловік  27.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:45:48  Чоловік  31.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:46:12  Чоловік  25.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:49:02  Чоловік  27.0                    Середня спеціальна
# 11.30.2022 10:49:16  Чоловік  25.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:49:39  Чоловік  23.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:50:29  Чоловік  36.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:50:57  Чоловік  25.0                              Дві вищі
# 11.30.2022 10:56:11  Чоловік  33.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 10:56:26    Жінка  44.0                              Дві вищі
# 11.30.2022 11:00:43    Жінка  26.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 11:03:31  Чоловік  21.0  Вища (бакалавр, спеціаліст, магістр)
# 11.30.2022 11:30:53  Чоловік  36.0                              Дві вищі
#
#                     scientific_degree       english_level  \
# Timestamp
# 11.30.2022 10:26:39             Немає            Advanced
# 11.30.2022 10:28:00             Немає            Advanced
# 11.30.2022 10:30:00             Немає            Advanced
# 11.30.2022 10:30:30             Немає  Upper-Intermediate
# 11.30.2022 10:30:53             Немає  Upper-Intermediate
# 11.30.2022 10:34:00             Немає  Upper-Intermediate
# 11.30.2022 10:35:35             Немає        Intermediate
# 11.30.2022 10:36:24             Немає            Advanced
# 11.30.2022 10:36:56             Немає        Intermediate
# 11.30.2022 10:37:46             Немає  Upper-Intermediate
# 11.30.2022 10:39:44             Немає  Upper-Intermediate
# 11.30.2022 10:39:47             Немає  Upper-Intermediate
# 11.30.2022 10:43:29             Немає        Intermediate
# 11.30.2022 10:45:02             Немає  Upper-Intermediate
# 11.30.2022 10:45:45             Немає  Upper-Intermediate
# 11.30.2022 10:45:48             Немає  Upper-Intermediate
# 11.30.2022 10:46:12             Немає        Intermediate
# 11.30.2022 10:49:02             Немає            Advanced
# 11.30.2022 10:49:16             Немає        Intermediate
# 11.30.2022 10:49:39             Немає        Intermediate
# 11.30.2022 10:50:29             Немає  Upper-Intermediate
# 11.30.2022 10:50:57             Немає        Intermediate
# 11.30.2022 10:56:11             Немає        Intermediate
# 11.30.2022 10:56:26             Немає            Advanced
# 11.30.2022 11:00:43             Немає    Pre-Intermediate
# 11.30.2022 11:03:31             Немає        Intermediate
# 11.30.2022 11:30:53             Немає        Intermediate
#
#                                                               position  \
# Timestamp
# 11.30.2022 10:26:39  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:28:00  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:30:00  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:30:30  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:30:53                                      Sales Manager
# 11.30.2022 10:34:00  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:35:35  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:36:24  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:36:56  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:37:46  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:39:44  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:39:47  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:43:29  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:45:02  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:45:45  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:45:48  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:46:12  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:49:02  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:49:16  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:49:39  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:50:29  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:50:57  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:56:11  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 10:56:26  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 11:00:43                                       HR/Recruiter
# 11.30.2022 11:03:31  Software Engineer (Junior, Middle, Senior, Tea...
# 11.30.2022 11:30:53  Software Engineer (Junior, Middle, Senior, Tea...
#
#                          title  use_code programming_language  \
# Timestamp
# 11.30.2022 10:26:39     Middle      <NA>                 Ruby
# 11.30.2022 10:28:00     Middle      <NA>            C# / .NET
# 11.30.2022 10:30:00     Middle      <NA>                 Rust
# 11.30.2022 10:30:30     Middle      <NA>           TypeScript
# 11.30.2022 10:30:53    Manager      <NA>                  NaN
# 11.30.2022 10:34:00     Middle      <NA>               Python
# 11.30.2022 10:35:35     Senior      <NA>               Kotlin
# 11.30.2022 10:36:24     Senior      <NA>            C# / .NET
# 11.30.2022 10:36:56     Middle      <NA>                  SQL
# 11.30.2022 10:37:46     Senior      <NA>                  PHP
# 11.30.2022 10:39:44  Architect      <NA>           TypeScript
# 11.30.2022 10:39:47     Middle      <NA>                 Java
# 11.30.2022 10:43:29     Middle      <NA>           TypeScript
# 11.30.2022 10:45:02  Team Lead      <NA>                  PHP
# 11.30.2022 10:45:45     Senior      <NA>                  PHP
# 11.30.2022 10:45:48     Senior      <NA>                Scala
# 11.30.2022 10:46:12  Tech Lead      <NA>                 Java
# 11.30.2022 10:49:02     Middle      <NA>               Python
# 11.30.2022 10:49:16     Middle      <NA>           TypeScript
# 11.30.2022 10:49:39     Middle      <NA>            C# / .NET
# 11.30.2022 10:50:29     Senior      <NA>            Інша мова
# 11.30.2022 10:50:57     Middle      <NA>           JavaScript
# 11.30.2022 10:56:11  Tech Lead      <NA>                 Java
# 11.30.2022 10:56:26     Junior      <NA>                 Java
# 11.30.2022 11:00:43     Middle      <NA>                  NaN
# 11.30.2022 11:03:31     Middle      <NA>           JavaScript
# 11.30.2022 11:30:53     Middle      <NA>           JavaScript
#
#                           specialization  \
# Timestamp
# 11.30.2022 10:26:39  Full Stack розробка
# 11.30.2022 10:28:00  Full Stack розробка
# 11.30.2022 10:30:00   Back-end  розробка
# 11.30.2022 10:30:30  Front-end  розробка
# 11.30.2022 10:30:53                  NaN
# 11.30.2022 10:34:00   Back-end  розробка
# 11.30.2022 10:35:35     Mobile  розробка
# 11.30.2022 10:36:24   Back-end  розробка
# 11.30.2022 10:36:56  Full Stack розробка
# 11.30.2022 10:37:46   Back-end  розробка
# 11.30.2022 10:39:44  Front-end  розробка
# 11.30.2022 10:39:47   Back-end  розробка
# 11.30.2022 10:43:29  Full Stack розробка
# 11.30.2022 10:45:02  Full Stack розробка
# 11.30.2022 10:45:45   Back-end  розробка
# 11.30.2022 10:45:48   Back-end  розробка
# 11.30.2022 10:46:12   Back-end  розробка
# 11.30.2022 10:49:02   Back-end  розробка
# 11.30.2022 10:49:16  Front-end  розробка
# 11.30.2022 10:49:39  Full Stack розробка
# 11.30.2022 10:50:29             Embedded
# 11.30.2022 10:50:57  Front-end  розробка
# 11.30.2022 10:56:11   Back-end  розробка
# 11.30.2022 10:56:26   Back-end  розробка
# 11.30.2022 11:00:43                  NaN
# 11.30.2022 11:03:31  Front-end  розробка
# 11.30.2022 11:30:53  Front-end  розробка
#
#                                                      area   company_type  \
# Timestamp
# 11.30.2022 10:26:39          Public services / Government     Продуктова
# 11.30.2022 10:28:00                                  Інша  Аутсорсингова
# 11.30.2022 10:30:00                            Blockchain     Продуктова
# 11.30.2022 10:30:30                            E-commerce  Аутстафінгова
# 11.30.2022 10:30:53                  Adtech / Advertising     Продуктова
# 11.30.2022 10:34:00                                Travel     Продуктова
# 11.30.2022 10:35:35                                   ERP  Аутсорсингова
# 11.30.2022 10:36:24                            E-commerce  Аутсорсингова
# 11.30.2022 10:36:56                                Retail     Продуктова
# 11.30.2022 10:37:46                            E-commerce     Продуктова
# 11.30.2022 10:39:44                     Fintech / Banking     Продуктова
# 11.30.2022 10:39:47          Fintech / Banking, Insurance  Аутсорсингова
# 11.30.2022 10:43:29                                  Інша  Аутсорсингова
# 11.30.2022 10:45:02                            E-commerce  Аутстафінгова
# 11.30.2022 10:45:45                    E-commerce, Retail  Аутсорсингова
# 11.30.2022 10:45:48                  Adtech / Advertising  Аутстафінгова
# 11.30.2022 10:46:12                     Fintech / Banking  Аутсорсингова
# 11.30.2022 10:49:02                     Fintech / Banking     Продуктова
# 11.30.2022 10:49:16              Fintech / Banking, Legal  Аутсорсингова
# 11.30.2022 10:49:39  Hardware, Internet of Things, Mobile  Аутсорсингова
# 11.30.2022 10:50:29                         Manufacturing  Аутсорсингова
# 11.30.2022 10:50:57      E-commerce, Medtech / Healthcare     Продуктова
# 11.30.2022 10:56:11                  Medtech / Healthcare  Аутстафінгова
# 11.30.2022 10:56:26                     Fintech / Banking  Аутсорсингова
# 11.30.2022 11:00:43                            E-commerce  Аутсорсингова
# 11.30.2022 11:03:31                              Big Data  Аутстафінгова
# 11.30.2022 11:30:53                    Edtech / Education  Аутсорсингова
#
#                      work_experience specialization_info
# Timestamp
# 11.30.2022 10:26:39              3.0                 NaN
# 11.30.2022 10:28:00              2.0                 NaN
# 11.30.2022 10:30:00              2.0                 NaN
# 11.30.2022 10:30:30              2.0                 NaN
# 11.30.2022 10:30:53              1.5                 NaN
# 11.30.2022 10:34:00              3.0                 NaN
# 11.30.2022 10:35:35             10.0                 NaN
# 11.30.2022 10:36:24              6.0                 NaN
# 11.30.2022 10:36:56             10.0                 NaN
# 11.30.2022 10:37:46              5.0                 NaN
# 11.30.2022 10:39:44             10.0                 NaN
# 11.30.2022 10:39:47              0.5                 NaN
# 11.30.2022 10:43:29              4.0                 NaN
# 11.30.2022 10:45:02              5.0                 NaN
# 11.30.2022 10:45:45             10.0                 NaN
# 11.30.2022 10:45:48              1.5                 NaN
# 11.30.2022 10:46:12              6.0                 NaN
# 11.30.2022 10:49:02              8.0                 NaN
# 11.30.2022 10:49:16              1.5                 NaN
# 11.30.2022 10:49:39              3.0                 NaN
# 11.30.2022 10:50:29             11.0                 NaN
# 11.30.2022 10:50:57              6.0                 NaN
# 11.30.2022 10:56:11             11.0                 NaN
# 11.30.2022 10:56:26              1.5                 NaN
# 11.30.2022 11:00:43              4.0                 NaN
# 11.30.2022 11:03:31              3.0                 NaN
# 11.30.2022 11:30:53              3.0                 NaN

# %% [markdown]
# Так як відсоток пропущених значень невеликий, можемо просто видалити відповідні рядки з датафрейму. Користаємось методом `dropna()`: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
dou = dou.dropna(subset=['salary'])
dou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13288 entries, 11.30.2022 10:26:37 to 01.09.2023 11:38
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employment_type       13288 non-null  object
#  1   in_ukraine            13288 non-null  bool
#  2   region                11538 non-null  object
#  3   salary                13288 non-null  float64
#  4   gender                13288 non-null  object
#  5   age                   13288 non-null  float64
#  6   education             13288 non-null  object
#  7   scientific_degree     13177 non-null  object
#  8   english_level         13288 non-null  object
#  9   position              13288 non-null  object
#  10  title                 13288 non-null  object
#  11  use_code              4874 non-null   boolean
#  12  programming_language  9035 non-null   object
#  13  specialization        9034 non-null   object
#  14  area                  13288 non-null  object
#  15  company_type          13288 non-null  object
#  16  work_experience       13288 non-null  float64
#  17  specialization_info   3009 non-null   object
# dtypes: bool(1), boolean(1), float64(3), object(13)
# memory usage: 1.8+ MB

# %% [markdown]
# Метод `describe()` можна застосовувати до декількох колонок одразу, або навіть до всього датасету.

# %%
dou[['age', 'work_experience']].describe()
# Out:
#                 age  work_experience
# count  13288.000000     13288.000000
# mean      29.321004         4.813855
# std        6.032051         3.797783
# min       14.000000         0.000000
# 25%       25.000000         2.000000
# 50%       29.000000         4.000000
# 75%       33.000000         7.000000
# max       63.000000        15.000000

# %% [markdown]
# Для первинної аналітики розподілу категоріальної змінної доцільно скористатися методом `value_counts()`, показавши у тому числі пропущені дані.

# %%
dou['programming_language'].value_counts(dropna=False)
# Out:
# programming_language
# NaN                                        4253
# JavaScript                                 1692
# Java                                       1237
# Python                                     1188
# C# / .NET                                  1176
# TypeScript                                 1175
# PHP                                         624
# Kotlin                                      285
# C++                                         251
# Swift                                       221
# SQL                                         200
# Go                                          165
# Ruby                                        157
# Інша мова                                   127
# Dart                                         96
# Scala                                        72
# Salesforce Apex                              59
# C                                            58
# Не можу обрати одну основну мову             57
# 1С                                           38
# Мови розробки БД (PL/SQL, Transact-SQL)      36
# Groovy                                       30
# Rust                                         27
# Elixir                                       15
# Pascal/Delphi                                 9
# R                                             9
# Perl                                          6
# Clojure                                       6
# Erlang                                        5
# ABAP                                          5
# Objective-C                                   4
# APL                                           2
# Flex / Flash / AIR                            2
# Haskell                                       1
# Name: count, dtype: int64

# %% [markdown]
# Для візуалізації розподілу значень категоріальної змінної користуємось стовпчиковою діаграмою (bar chart, bar plot).

# %%
dou['programming_language'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
dou['programming_language'].value_counts().head(10).sort_values().plot(kind='barh')
plt.title('Top 10 programming languages in Ukraine (dou.ua, December 2022)')
plt.show()

# %% [markdown]
# ## Aggregating Data. Pivot Tables
#
# To aggregate data in Pandas, there are two main approaches:
# * **GROUP BY** (similar to the SQL operation)
# * **Pivot tables** (similar to the operation in spreadsheets).

# %% [markdown]
# ### GROUP BY
#
# Стаття з документації бібліотеки: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html
#
# Стаття з підручника: https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html

# %% [markdown]
# Наведемо для початку простий приклад застосування GROUP BY: виведемо **медіанну зарплату** для кожного з **рівнів володіння англійською мовою**.
#
# Отже, у даному випадку в нас одна категоріальна змінна для групування (`english_level`) та одна змінна для агрегування значень (`salary`), до якої застосовуємо агрегатну функцію `median`.

# %%
dou.groupby('english_level')['salary'].median().sort_values(ascending=False)
# Out:
# english_level
# Advanced              3500.0
# Upper-Intermediate    3300.0
# Intermediate          2125.0
# Pre-Intermediate      1404.0
# Elementary            1155.0
# Name: salary, dtype: float64

# %% [markdown]
# Візуалізувати результат GROUP BY можна за допомогою bar chart.

# %%
dou.groupby('english_level')['salary'].median().sort_values().plot(kind='barh')
plt.xlabel('Median of salary, $ per month')
plt.show()

# %% [markdown]
# Ми можемо застосовувати декілька агрегатних функцій для кожної групи. У такому випадку перелічуємо їх як список у методі `agg` (або `aggregate`). Знайдемо мінімальну, максимальну та медіанну зарплату для кожного рівня англійської.

# %%
dou.groupby('english_level')['salary'].agg(['min', 'median', 'max'])
# Out:
#                       min  median      max
# english_level
# Advanced            160.0  3500.0  17000.0
# Elementary           50.0  1155.0  10000.0
# Intermediate        100.0  2125.0  16000.0
# Pre-Intermediate     80.0  1404.0   8500.0
# Upper-Intermediate  100.0  3300.0  19500.0

# %%
dou.groupby('english_level')['salary'].agg(['min', 'median', 'max']).sort_values('median', ascending=False)
# Out:
#                       min  median      max
# english_level
# Advanced            160.0  3500.0  17000.0
# Upper-Intermediate  100.0  3300.0  19500.0
# Intermediate        100.0  2125.0  16000.0
# Pre-Intermediate     80.0  1404.0   8500.0
# Elementary           50.0  1155.0  10000.0

# %% [markdown]
# Операцію групування можна робити таким чином, щоб агрегування відбувалося за декількома колонками. До кожної колонки при цьому можна застососувати свою агрегатну функцію.
#
# Обчислимо середній досвід роботи та медіанну зарплату для кожного з тайтлів співробітників.

# %%
group_by_title = dou.groupby('title')[['work_experience', 'salary']].agg({'work_experience': 'mean',
                                                                          'salary': 'median'}).sort_values('salary', ascending=False)
np.round(group_by_title)
# Out:
#                 work_experience  salary
# title
# Architect                  10.0  6400.0
# Tech Lead                   9.0  5500.0
# Senior                      7.0  4500.0
# Team Lead                   7.0  4400.0
# Head                        7.0  4000.0
# Manager                     6.0  3200.0
# Middle                      4.0  2300.0
# Немає тайтлу                4.0  1500.0
# Junior                      2.0   900.0
# Intern/Trainee              1.0   450.0

# %%
group_by_title = dou.groupby('title')[['work_experience', 'salary']].agg({'work_experience': [np.min, np.mean, np.max],
                                                                          'salary': 'median'})
np.round(group_by_title)
# Out:
#                work_experience              salary
#                           amin  mean  amax  median
# title
# Architect                  0.0  10.0  15.0  6400.0
# Head                       0.0   7.0  15.0  4000.0
# Intern/Trainee             0.0   1.0  15.0   450.0
# Junior                     0.0   2.0  15.0   900.0
# Manager                    0.0   6.0  15.0  3200.0
# Middle                     0.0   4.0  15.0  2300.0
# Senior                     0.0   7.0  15.0  4500.0
# Team Lead                  0.0   7.0  15.0  4400.0
# Tech Lead                  0.0   9.0  15.0  5500.0
# Немає тайтлу               0.0   4.0  15.0  1500.0

# %%
group_by_title.columns
# Out:
# MultiIndex([('work_experience',   'amin'),
#             ('work_experience',   'mean'),
#             ('work_experience',   'amax'),
#             (         'salary', 'median')],
#            )

# %%
group_by_title = dou.groupby('title')[['work_experience', 'salary']].agg({'work_experience': [np.min, np.mean, np.max],
                                                                          'salary': 'median'}).sort_values(('salary', 'median'), ascending=False)
np.round(group_by_title)
# Out:
#                work_experience              salary
#                           amin  mean  amax  median
# title
# Architect                  0.0  10.0  15.0  6400.0
# Tech Lead                  0.0   9.0  15.0  5500.0
# Senior                     0.0   7.0  15.0  4500.0
# Team Lead                  0.0   7.0  15.0  4400.0
# Head                       0.0   7.0  15.0  4000.0
# Manager                    0.0   6.0  15.0  3200.0
# Middle                     0.0   4.0  15.0  2300.0
# Немає тайтлу               0.0   4.0  15.0  1500.0
# Junior                     0.0   2.0  15.0   900.0
# Intern/Trainee             0.0   1.0  15.0   450.0

# %% [markdown]
# Нарешті, можемо робити групування за декількома категоріями, у такому випадку перелічуємо ці категорії у вигляді списку.
#
# Подивимось на медіанні зарплати розробників та тестувальників по кожному тайтлу.

# %%
programmers_qa = dou['position'].value_counts().head(2).index
print(programmers_qa)
# Out:
# Index(['Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)', 'QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)'], dtype='object')

# %%
dou[dou['position'].isin(programmers_qa)].groupby(['title', 'position'])['salary'].median()
# Out:
# title           position
# Architect       QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            5625.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    6500.0
# Head            QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            4850.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    5612.5
# Intern/Trainee  QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)             475.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)     450.0
# Junior          QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)             800.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    1000.0
# Manager         QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            4000.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    6600.0
# Middle          QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            1850.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    2600.0
# Senior          QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            3400.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    5000.0
# Team Lead       QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            3500.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    5100.0
# Tech Lead       QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)            4400.0
#                 Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)    5875.0
# Name: salary, dtype: float64

# %%
dou[dou['position'].isin(programmers_qa)].groupby(['title', 'position'])['salary'].median().index
# Out:
# MultiIndex([(     'Architect', ...),
#             (     'Architect', ...),
#             (          'Head', ...),
#             (          'Head', ...),
#             ('Intern/Trainee', ...),
#             ('Intern/Trainee', ...),
#             (        'Junior', ...),
#             (        'Junior', ...),
#             (       'Manager', ...),
#             (       'Manager', ...),
#             (        'Middle', ...),
#             (        'Middle', ...),
#             (        'Senior', ...),
#             (        'Senior', ...),
#             (     'Team Lead', ...),
#             (     'Team Lead', ...),
#             (     'Tech Lead', ...),
#             (     'Tech Lead', ...)],
#            names=['title', 'position'])

# %% [markdown]
# ###  Зведені таблиці (pivot tables)
#
# Стаття з документації: https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html
#
# Стаття з підручника: https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# Зведені таблиці, так само як і GROUP BY, дозволяють обчислювати агрегатні функції за категоріями. Але при цьому категорії можна розташовувати як у рядках (параметр `index`), так і у стовпчиках (параметр `columns`). Колонка, за якою обчислюється агрегатна функція по кожній групі, передається у параметрі `values`, а сама агрегатна функція --- у параметрі `aggfunc`).
#
# Оформимо попередній приклад з розробниками та тестувальниками у вигляді зведеної таблиці.

# %%
dou[dou['position'].isin(programmers_qa)].pivot_table(index='title',
                                                      columns='position',
                                                      values='salary',
                                                      aggfunc='median')
# Out:
# position        QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)  \
# title
# Architect                                                  5625.0
# Head                                                       4850.0
# Intern/Trainee                                              475.0
# Junior                                                      800.0
# Manager                                                    4000.0
# Middle                                                     1850.0
# Senior                                                     3400.0
# Team Lead                                                  3500.0
# Tech Lead                                                  4400.0
#
# position        Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)
# title
# Architect                                                  6500.0
# Head                                                       5612.5
# Intern/Trainee                                              450.0
# Junior                                                     1000.0
# Manager                                                    6600.0
# Middle                                                     2600.0
# Senior                                                     5000.0
# Team Lead                                                  5100.0
# Tech Lead                                                  5875.0

# %%
dou[dou['position'].isin(programmers_qa)].pivot_table(index='title',
                                                      columns='position',
                                                      values='salary',
                                                      aggfunc='median').rename(columns={'QA Engineer (Junior, Middle, Senior, Team/Tech Lead, Manager)': 'QA',
                                                                                        'Software Engineer (Junior, Middle, Senior, Team/Tech Lead, Architect)': 'Programmers'})
# Out:
# position            QA  Programmers
# title
# Architect       5625.0       6500.0
# Head            4850.0       5612.5
# Intern/Trainee   475.0        450.0
# Junior           800.0       1000.0
# Manager         4000.0       6600.0
# Middle          1850.0       2600.0
# Senior          3400.0       5000.0
# Team Lead       3500.0       5100.0
# Tech Lead       4400.0       5875.0

# %% [markdown]
# Обчислимо тепер медіанну зарплату для кожного тайтла та для кожного рівня володіння англійською для цього тайтла.

# %%
dou.pivot_table(index='title', columns='english_level', values='salary', aggfunc=np.median)
# Out:
# english_level   Advanced  Elementary  Intermediate  Pre-Intermediate  \
# title
# Architect         7000.0         NaN        5450.0            2900.0
# Head              5000.0      1500.0        3500.0            2400.0
# Intern/Trainee     500.0       500.0         400.0             400.0
# Junior            1000.0       600.0         900.0             800.0
# Manager           4000.0      1120.0        2100.0            1225.0
# Middle            2500.0      1500.0        2200.0            1825.0
# Senior            4750.0      2500.0        4100.0            3500.0
# Team Lead         5000.0      2100.0        3800.0            2850.0
# Tech Lead         6000.0      5000.0        5000.0            4000.0
# Немає тайтлу      2075.0       550.0        1300.0             934.0
#
# english_level   Upper-Intermediate
# title
# Architect                   6400.0
# Head                        4000.0
# Intern/Trainee               485.0
# Junior                      1000.0
# Manager                     3600.0
# Middle                      2500.0
# Senior                      4750.0
# Team Lead                   4655.0
# Tech Lead                   5650.0
# Немає тайтлу                1600.0

# %% [markdown]
# Для зміни порядку слідування груп у рядках та стовпчиках можемо скористатись методом `reindex()` із параметром `axis`.

# %%
english_order = ['Elementary', 'Pre-Intermediate', 'Intermediate', 'Upper-Intermediate', 'Advanced']
title_order = dou.groupby('title')['salary'].median().sort_values(ascending=False).index
df_pivot = dou.pivot_table(index='title', columns='english_level', values='salary', aggfunc=np.median)
df_pivot.reindex(english_order, axis=1).reindex(title_order, axis=0)
# Out:
# english_level   Elementary  Pre-Intermediate  Intermediate  \
# title
# Architect              NaN            2900.0        5450.0
# Tech Lead           5000.0            4000.0        5000.0
# Senior              2500.0            3500.0        4100.0
# Team Lead           2100.0            2850.0        3800.0
# Head                1500.0            2400.0        3500.0
# Manager             1120.0            1225.0        2100.0
# Middle              1500.0            1825.0        2200.0
# Немає тайтлу         550.0             934.0        1300.0
# Junior               600.0             800.0         900.0
# Intern/Trainee       500.0             400.0         400.0
#
# english_level   Upper-Intermediate  Advanced
# title
# Architect                   6400.0    7000.0
# Tech Lead                   5650.0    6000.0
# Senior                      4750.0    4750.0
# Team Lead                   4655.0    5000.0
# Head                        4000.0    5000.0
# Manager                     3600.0    4000.0
# Middle                      2500.0    2500.0
# Немає тайтлу                1600.0    2075.0
# Junior                      1000.0    1000.0
# Intern/Trainee               485.0     500.0

# %% [markdown]
# Візуалізуємо отриманий результат за допомогою теплової карти (скористаємось діаграмою `heatmap` бібліотеки `seaborn`).

# %%
sns.heatmap(df_pivot.reindex(english_order, axis=1).reindex(title_order, axis=0))
plt.show()
